# %%
from __future__ import print_function
import os
import argparse
import sys
sys.argv
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from torchvision import datasets, transforms
import random
import numpy as np
SEED=1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.benchmark = False
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion * planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])
def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
if not os.path.exists('model-resnet-epoch76.pt'):
    os.makedirs('model-resnet-epoch76.pt')
use_cuda = not False and torch.cuda.is_available()
torch.manual_seed(1)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
net=ResNet18()
net.load_state_dict(torch.load('model-resnet-epoch150.pt'))
net.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=100, bias=True)
# )

# %%
#PGD_adversarial_training
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import os

#from models import *

learning_rate = 0.1
epsilon = 0.0314
k = 7
alpha = 0.00784
file_name = 'pgd_adversarial_training'

device = 'cuda' if torch.cuda.is_available() else 'cpu'

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)

class LinfPGDAttack(object):
    def __init__(self, model):
        self.model = model

    def perturb(self, x_natural, y):
        x = x_natural.detach()
        x = x + torch.zeros_like(x).uniform_(-epsilon, epsilon)
        for i in range(k):
            x.requires_grad_()
            with torch.enable_grad():
                logits = self.model(x)
                loss = F.cross_entropy(logits, y)
            grad = torch.autograd.grad(loss, [x])[0]
            x = x.detach() + alpha * torch.sign(grad.detach())
            x = torch.min(torch.max(x, x_natural - epsilon), x_natural + epsilon)
            x = torch.clamp(x, 0, 1)
        return x

def attack(x, y, model, adversary):
    model_copied = copy.deepcopy(model)
    model_copied.eval()
    adversary.model = model_copied
    adv = adversary.perturb(x, y)
    return adv


adversary = LinfPGDAttack(net)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        adv = adversary.perturb(inputs, targets)
        adv_outputs = net(adv)
        loss = criterion(adv_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = adv_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 10 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current adversarial train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current adversarial train loss:', loss.item())

    print('\nTotal adversarial train accuarcy:', 100. * correct / total)
    print('Total adversarial train loss:', train_loss)

def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    benign_loss = 0
    adv_loss = 0
    benign_correct = 0
    adv_correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            total += targets.size(0)

            outputs = net(inputs)
            loss = criterion(outputs, targets)
            benign_loss += loss.item()

            _, predicted = outputs.max(1)
            benign_correct += predicted.eq(targets).sum().item()

            if batch_idx % 10 == 0:
                print('\nCurrent batch:', str(batch_idx))
                print('Current benign test accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
                print('Current benign test loss:', loss.item())

            adv = adversary.perturb(inputs, targets)
            adv_outputs = net(adv)
            loss = criterion(adv_outputs, targets)
            adv_loss += loss.item()

            _, predicted = adv_outputs.max(1)
            adv_correct += predicted.eq(targets).sum().item()

            if batch_idx % 10 == 0:
                print('Current adversarial test accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
                print('Current adversarial test loss:', loss.item())

    print('\nTotal benign test accuarcy:', 100. * benign_correct / total)
    print('Total adversarial test Accuarcy:', 100. * adv_correct / total)
    print('Total benign test loss:', benign_loss)
    print('Total adversarial test loss:', adv_loss)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 5:
        lr /= 100
    if epoch >= 50:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

for epoch in range(0, 10):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data\cifar-100-python.tar.gz
# 100%|██████████████████████████████████████████████████████████████| 169001437/169001437 [00:14<00:00, 11795845.51it/s]
# Extracting ./data\cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
#
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.0
# Current adversarial train loss: 20.947202682495117
#
# Current batch: 10
# Current adversarial train accuracy: 0.03125
# Current adversarial train loss: 4.933088779449463
#
# Current batch: 20
# Current adversarial train accuracy: 0.0390625
# Current adversarial train loss: 4.428069114685059
#
# Current batch: 30
# Current adversarial train accuracy: 0.0390625
# Current adversarial train loss: 4.4828057289123535
#
# Current batch: 40
# Current adversarial train accuracy: 0.046875
# Current adversarial train loss: 4.259268283843994
#
# Current batch: 50
# Current adversarial train accuracy: 0.0625
# Current adversarial train loss: 4.384592533111572
#
# Current batch: 60
# Current adversarial train accuracy: 0.0546875
# Current adversarial train loss: 4.27225923538208
#
# Current batch: 70
# Current adversarial train accuracy: 0.03125
# Current adversarial train loss: 4.255049228668213
#
# Current batch: 80
# Current adversarial train accuracy: 0.0703125
# Current adversarial train loss: 4.091454029083252
#
# Current batch: 90
# Current adversarial train accuracy: 0.0546875
# Current adversarial train loss: 4.103222846984863
#
# Current batch: 100
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 4.091744899749756
#
# Current batch: 110
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 3.9377248287200928
#
# Current batch: 120
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 3.8962016105651855
#
# Current batch: 130
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 3.954688787460327
#
# Current batch: 140
# Current adversarial train accuracy: 0.09375
# Current adversarial train loss: 3.8529138565063477
#
# Current batch: 150
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 4.018157005310059
#
# Current batch: 160
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 3.906489849090576
#
# Current batch: 170
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 3.917941093444824
#
# Current batch: 180
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 3.860966682434082
#
# Current batch: 190
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 3.772411584854126
#
# Current batch: 200
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 3.988215446472168
#
# Current batch: 210
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 3.782627582550049
#
# Current batch: 220
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 3.787384033203125
#
# Current batch: 230
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 3.7305188179016113
#
# Current batch: 240
# Current adversarial train accuracy: 0.0859375
# Current adversarial train loss: 3.9528350830078125
#
# Current batch: 250
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 3.7533435821533203
#
# Current batch: 260
# Current adversarial train accuracy: 0.09375
# Current adversarial train loss: 3.8650732040405273
#
# Current batch: 270
# Current adversarial train accuracy: 0.15625
# Current adversarial train loss: 3.879840612411499
#
# Current batch: 280
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 3.931389808654785
#
# Current batch: 290
# Current adversarial train accuracy: 0.0859375
# Current adversarial train loss: 3.844283103942871
#
# Current batch: 300
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 3.7865262031555176
#
# Current batch: 310
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 3.6650242805480957
#
# Current batch: 320
# Current adversarial train accuracy: 0.15625
# Current adversarial train loss: 3.6389777660369873
#
# Current batch: 330
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 3.6132476329803467
#
# Current batch: 340
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 3.6798949241638184
#
# Current batch: 350
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 3.605363368988037
#
# Current batch: 360
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 3.9175174236297607
#
# Current batch: 370
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 3.3466556072235107
#
# Current batch: 380
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 3.8481032848358154
#
# Current batch: 390
# Current adversarial train accuracy: 0.1625
# Current adversarial train loss: 3.6660099029541016
#
# Total adversarial train accuarcy: 10.486
# Total adversarial train loss: 1617.8517065048218
#
# [ Test epoch: 0 ]
#
# Current batch: 0
# Current benign test accuracy: 0.38
# Current benign test loss: 2.723083257675171
# Current adversarial test accuracy: 0.18
# Current adversarial test loss: 3.5070040225982666
#
# Current batch: 10
# Current benign test accuracy: 0.3
# Current benign test loss: 2.865536689758301
# Current adversarial test accuracy: 0.12
# Current adversarial test loss: 3.6529929637908936
#
# Current batch: 20
# Current benign test accuracy: 0.37
# Current benign test loss: 2.913757085800171
# Current adversarial test accuracy: 0.15
# Current adversarial test loss: 3.696397304534912
#
# Current batch: 30
# Current benign test accuracy: 0.32
# Current benign test loss: 2.8814704418182373
# Current adversarial test accuracy: 0.16
# Current adversarial test loss: 3.6423113346099854
#
# Current batch: 40
# Current benign test accuracy: 0.34
# Current benign test loss: 2.7686526775360107
# Current adversarial test accuracy: 0.21
# Current adversarial test loss: 3.515916347503662
#
# Current batch: 50
# Current benign test accuracy: 0.38
# Current benign test loss: 2.85195255279541
# Current adversarial test accuracy: 0.13
# Current adversarial test loss: 3.650115966796875
#
# Current batch: 60
# Current benign test accuracy: 0.36
# Current benign test loss: 2.7704617977142334
# Current adversarial test accuracy: 0.15
# Current adversarial test loss: 3.5370659828186035
#
# Current batch: 70
# Current benign test accuracy: 0.29
# Current benign test loss: 2.979250907897949
# Current adversarial test accuracy: 0.14
# Current adversarial test loss: 3.6899912357330322
#
# Current batch: 80
# Current benign test accuracy: 0.33
# Current benign test loss: 3.0074002742767334
# Current adversarial test accuracy: 0.15
# Current adversarial test loss: 3.7840147018432617
#
# Current batch: 90
# Current benign test accuracy: 0.35
# Current benign test loss: 2.8496060371398926
# Current adversarial test accuracy: 0.13
# Current adversarial test loss: 3.635789155960083
#
# Total benign test accuarcy: 33.07
# Total adversarial test Accuarcy: 16.15
# Total benign test loss: 284.3658232688904
# Total adversarial test loss: 359.58271884918213
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 3.4259932041168213
#
# Current batch: 10
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 3.672247886657715
#
# Current batch: 20
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 3.756868839263916
#
# Current batch: 30
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 3.417642831802368
#
# Current batch: 40
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.3739397525787354
#
# Current batch: 50
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.3247897624969482
#
# Current batch: 60
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 3.675609588623047
#
# Current batch: 70
# Current adversarial train accuracy: 0.15625
# Current adversarial train loss: 3.5398340225219727
#
# Current batch: 80
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 3.3383121490478516
#
# Current batch: 90
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 3.4075124263763428
#
# Current batch: 100
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.5105037689208984
#
# Current batch: 110
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 3.5060713291168213
#
# Current batch: 120
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 3.23685622215271
#
# Current batch: 130
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.436549663543701
#
# Current batch: 140
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 3.496403217315674
#
# Current batch: 150
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 3.4212634563446045
#
# Current batch: 160
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 3.6653590202331543
#
# Current batch: 170
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 3.463707447052002
#
# Current batch: 180
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.3739190101623535
#
# Current batch: 190
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.2370219230651855
#
# Current batch: 200
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.316662311553955
#
# Current batch: 210
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.415572166442871
#
# Current batch: 220
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 3.4765634536743164
#
# Current batch: 230
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 3.438626766204834
#
# Current batch: 240
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 3.454941749572754
#
# Current batch: 250
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 3.4242427349090576
#
# Current batch: 260
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 3.6304287910461426
#
# Current batch: 270
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 3.746255397796631
#
# Current batch: 280
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 3.576263427734375
#
# Current batch: 290
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.4478626251220703
#
# Current batch: 300
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 3.4991984367370605
#
# Current batch: 310
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 3.2656214237213135
#
# Current batch: 320
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.4108822345733643
#
# Current batch: 330
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.5988376140594482
#
# Current batch: 340
# Current adversarial train accuracy: 0.15625
# Current adversarial train loss: 3.4946179389953613
#
# Current batch: 350
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 3.466864824295044
#
# Current batch: 360
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.420413017272949
#
# Current batch: 370
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.3618290424346924
#
# Current batch: 380
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.255953073501587
#
# Current batch: 390
# Current adversarial train accuracy: 0.225
# Current adversarial train loss: 3.376105785369873
#
# Total adversarial train accuarcy: 17.48
# Total adversarial train loss: 1352.3532197475433
#
# [ Test epoch: 1 ]
#
# Current batch: 0
# Current benign test accuracy: 0.47
# Current benign test loss: 2.3316450119018555
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.3448541164398193
#
# Current batch: 10
# Current benign test accuracy: 0.4
# Current benign test loss: 2.5176355838775635
# Current adversarial test accuracy: 0.15
# Current adversarial test loss: 3.545957326889038
#
# Current batch: 20
# Current benign test accuracy: 0.42
# Current benign test loss: 2.510256767272949
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.5507514476776123
#
# Current batch: 30
# Current benign test accuracy: 0.43
# Current benign test loss: 2.3493590354919434
# Current adversarial test accuracy: 0.21
# Current adversarial test loss: 3.317927598953247
#
# Current batch: 40
# Current benign test accuracy: 0.46
# Current benign test loss: 2.3812050819396973
# Current adversarial test accuracy: 0.23
# Current adversarial test loss: 3.3642737865448
#
# Current batch: 50
# Current benign test accuracy: 0.44
# Current benign test loss: 2.371898889541626
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.435917615890503
#
# Current batch: 60
# Current benign test accuracy: 0.43
# Current benign test loss: 2.3173253536224365
# Current adversarial test accuracy: 0.21
# Current adversarial test loss: 3.2945122718811035
#
# Current batch: 70
# Current benign test accuracy: 0.39
# Current benign test loss: 2.5589516162872314
# Current adversarial test accuracy: 0.15
# Current adversarial test loss: 3.513746738433838
#
# Current batch: 80
# Current benign test accuracy: 0.39
# Current benign test loss: 2.4565656185150146
# Current adversarial test accuracy: 0.2
# Current adversarial test loss: 3.4540905952453613
#
# Current batch: 90
# Current benign test accuracy: 0.4
# Current benign test loss: 2.429023504257202
# Current adversarial test accuracy: 0.21
# Current adversarial test loss: 3.4316375255584717
#
# Total benign test accuarcy: 42.67
# Total adversarial test Accuarcy: 19.44
# Total benign test loss: 240.46101140975952
# Total adversarial test loss: 339.57166600227356
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 3.207890748977661
#
# Current batch: 10
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 3.08677077293396
#
# Current batch: 20
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 3.4346718788146973
#
# Current batch: 30
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 3.1437184810638428
#
# Current batch: 40
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.265040874481201
#
# Current batch: 50
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 3.3296918869018555
#
# Current batch: 60
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.317582130432129
#
# Current batch: 70
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 3.1815223693847656
#
# Current batch: 80
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 3.252162456512451
#
# Current batch: 90
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 3.1882951259613037
#
# Current batch: 100
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 3.2527921199798584
#
# Current batch: 110
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 3.372191905975342
#
# Current batch: 120
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 3.40303111076355
#
# Current batch: 130
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.2878081798553467
#
# Current batch: 140
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 3.4052810668945312
#
# Current batch: 150
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 3.172245740890503
#
# Current batch: 160
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 3.239037275314331
#
# Current batch: 170
# Current adversarial train accuracy: 0.15625
# Current adversarial train loss: 3.427314281463623
#
# Current batch: 180
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.218970537185669
#
# Current batch: 190
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 3.3230831623077393
#
# Current batch: 200
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.2797701358795166
#
# Current batch: 210
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 3.0554885864257812
#
# Current batch: 220
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.100830554962158
#
# Current batch: 230
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 3.2033751010894775
#
# Current batch: 240
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 3.327901601791382
#
# Current batch: 250
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 3.3816568851470947
#
# Current batch: 260
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.2356841564178467
#
# Current batch: 270
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 3.301804542541504
#
# Current batch: 280
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 3.3738362789154053
#
# Current batch: 290
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.3780357837677
#
# Current batch: 300
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 3.32427716255188
#
# Current batch: 310
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.2466514110565186
#
# Current batch: 320
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.341745138168335
#
# Current batch: 330
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.1492457389831543
#
# Current batch: 340
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.2472214698791504
#
# Current batch: 350
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.199702024459839
#
# Current batch: 360
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.1001107692718506
#
# Current batch: 370
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.225081443786621
#
# Current batch: 380
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 3.16139554977417
#
# Current batch: 390
# Current adversarial train accuracy: 0.175
# Current adversarial train loss: 3.286804676055908
#
# Total adversarial train accuarcy: 20.86
# Total adversarial train loss: 1270.0226044654846
#
# [ Test epoch: 2 ]
#
# Current batch: 0
# Current benign test accuracy: 0.53
# Current benign test loss: 2.0826964378356934
# Current adversarial test accuracy: 0.22
# Current adversarial test loss: 3.1821184158325195
#
# Current batch: 10
# Current benign test accuracy: 0.43
# Current benign test loss: 2.2268502712249756
# Current adversarial test accuracy: 0.19
# Current adversarial test loss: 3.3077564239501953
#
# Current batch: 20
# Current benign test accuracy: 0.43
# Current benign test loss: 2.2810912132263184
# Current adversarial test accuracy: 0.27
# Current adversarial test loss: 3.3929202556610107
#
# Current batch: 30
# Current benign test accuracy: 0.49
# Current benign test loss: 2.2312378883361816
# Current adversarial test accuracy: 0.22
# Current adversarial test loss: 3.2717459201812744
#
# Current batch: 40
# Current benign test accuracy: 0.49
# Current benign test loss: 2.171433925628662
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.1796536445617676
#
# Current batch: 50
# Current benign test accuracy: 0.44
# Current benign test loss: 2.1182315349578857
# Current adversarial test accuracy: 0.29
# Current adversarial test loss: 3.180110216140747
#
# Current batch: 60
# Current benign test accuracy: 0.46
# Current benign test loss: 2.130784273147583
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.203167200088501
#
# Current batch: 70
# Current benign test accuracy: 0.41
# Current benign test loss: 2.330110549926758
# Current adversarial test accuracy: 0.19
# Current adversarial test loss: 3.4074957370758057
#
# Current batch: 80
# Current benign test accuracy: 0.38
# Current benign test loss: 2.434715747833252
# Current adversarial test accuracy: 0.23
# Current adversarial test loss: 3.51259708404541
#
# Current batch: 90
# Current benign test accuracy: 0.43
# Current benign test loss: 2.3191771507263184
# Current adversarial test accuracy: 0.17
# Current adversarial test loss: 3.37351131439209
#
# Total benign test accuarcy: 45.4
# Total adversarial test Accuarcy: 21.64
# Total benign test loss: 223.30515122413635
# Total adversarial test loss: 329.4435167312622
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 3.3225607872009277
#
# Current batch: 10
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 3.062385082244873
#
# Current batch: 20
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.030918598175049
#
# Current batch: 30
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.2205147743225098
#
# Current batch: 40
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.1109931468963623
#
# Current batch: 50
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.2650928497314453
#
# Current batch: 60
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.025200843811035
#
# Current batch: 70
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 3.116279125213623
#
# Current batch: 80
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.175215482711792
#
# Current batch: 90
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 3.1575875282287598
#
# Current batch: 100
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 3.3964967727661133
#
# Current batch: 110
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.30096173286438
#
# Current batch: 120
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 3.1374828815460205
#
# Current batch: 130
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.9947149753570557
#
# Current batch: 140
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 3.399298906326294
#
# Current batch: 150
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 3.3541924953460693
#
# Current batch: 160
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.1811323165893555
#
# Current batch: 170
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.2682788372039795
#
# Current batch: 180
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 3.065241813659668
#
# Current batch: 190
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.057183027267456
#
# Current batch: 200
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.1630167961120605
#
# Current batch: 210
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 3.1186861991882324
#
# Current batch: 220
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 3.0245044231414795
#
# Current batch: 230
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.2999846935272217
#
# Current batch: 240
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.9242730140686035
#
# Current batch: 250
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 3.095421075820923
#
# Current batch: 260
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 3.059723377227783
#
# Current batch: 270
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.220491886138916
#
# Current batch: 280
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 3.221656084060669
#
# Current batch: 290
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.3654427528381348
#
# Current batch: 300
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 3.083317518234253
#
# Current batch: 310
# Current adversarial train accuracy: 0.15625
# Current adversarial train loss: 3.2685139179229736
#
# Current batch: 320
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 3.4913599491119385
#
# Current batch: 330
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.3677587509155273
#
# Current batch: 340
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.1481261253356934
#
# Current batch: 350
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 3.4352777004241943
#
# Current batch: 360
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 3.0902390480041504
#
# Current batch: 370
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.0913379192352295
#
# Current batch: 380
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 3.1007192134857178
#
# Current batch: 390
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 3.10874342918396
#
# Total adversarial train accuarcy: 22.818
# Total adversarial train loss: 1227.9874436855316
#
# [ Test epoch: 3 ]
#
# Current batch: 0
# Current benign test accuracy: 0.6
# Current benign test loss: 2.005058526992798
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.073423147201538
#
# Current batch: 10
# Current benign test accuracy: 0.42
# Current benign test loss: 2.2863447666168213
# Current adversarial test accuracy: 0.18
# Current adversarial test loss: 3.426344394683838
#
# Current batch: 20
# Current benign test accuracy: 0.46
# Current benign test loss: 2.2194669246673584
# Current adversarial test accuracy: 0.23
# Current adversarial test loss: 3.3112475872039795
#
# Current batch: 30
# Current benign test accuracy: 0.42
# Current benign test loss: 2.2972943782806396
# Current adversarial test accuracy: 0.18
# Current adversarial test loss: 3.3800747394561768
#
# Current batch: 40
# Current benign test accuracy: 0.5
# Current benign test loss: 2.0887889862060547
# Current adversarial test accuracy: 0.27
# Current adversarial test loss: 3.1030702590942383
#
# Current batch: 50
# Current benign test accuracy: 0.53
# Current benign test loss: 2.076421022415161
# Current adversarial test accuracy: 0.3
# Current adversarial test loss: 3.158665657043457
#
# Current batch: 60
# Current benign test accuracy: 0.52
# Current benign test loss: 2.1324265003204346
# Current adversarial test accuracy: 0.21
# Current adversarial test loss: 3.2058217525482178
#
# Current batch: 70
# Current benign test accuracy: 0.45
# Current benign test loss: 2.308553695678711
# Current adversarial test accuracy: 0.19
# Current adversarial test loss: 3.38664174079895
#
# Current batch: 80
# Current benign test accuracy: 0.48
# Current benign test loss: 2.3329901695251465
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 3.3818252086639404
#
# Current batch: 90
# Current benign test accuracy: 0.49
# Current benign test loss: 2.1625311374664307
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.2019646167755127
#
# Total benign test accuarcy: 47.88
# Total adversarial test Accuarcy: 22.5
# Total benign test loss: 216.88792264461517
# Total adversarial test loss: 322.5612745285034
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 3.0287797451019287
#
# Current batch: 10
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.0234391689300537
#
# Current batch: 20
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.997670888900757
#
# Current batch: 30
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 3.0177907943725586
#
# Current batch: 40
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 3.2797789573669434
#
# Current batch: 50
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.9191672801971436
#
# Current batch: 60
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.936864137649536
#
# Current batch: 70
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 3.0108304023742676
#
# Current batch: 80
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.2464518547058105
#
# Current batch: 90
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 3.0711464881896973
#
# Current batch: 100
# Current adversarial train accuracy: 0.15625
# Current adversarial train loss: 3.2561562061309814
#
# Current batch: 110
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 2.8330061435699463
#
# Current batch: 120
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 3.080914258956909
#
# Current batch: 130
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.9170446395874023
#
# Current batch: 140
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 3.062952995300293
#
# Current batch: 150
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 3.3430609703063965
#
# Current batch: 160
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 2.974872589111328
#
# Current batch: 170
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.021977424621582
#
# Current batch: 180
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.9908225536346436
#
# Current batch: 190
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 3.066411256790161
#
# Current batch: 200
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 3.128817081451416
#
# Current batch: 210
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.9469194412231445
#
# Current batch: 220
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 3.252929925918579
#
# Current batch: 230
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 3.1342597007751465
#
# Current batch: 240
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.9638023376464844
#
# Current batch: 250
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.128373384475708
#
# Current batch: 260
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.213287830352783
#
# Current batch: 270
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.0636026859283447
#
# Current batch: 280
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.21809458732605
#
# Current batch: 290
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.360938549041748
#
# Current batch: 300
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 2.9995250701904297
#
# Current batch: 310
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 3.0999951362609863
#
# Current batch: 320
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.7916133403778076
#
# Current batch: 330
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.1943986415863037
#
# Current batch: 340
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.8750436305999756
#
# Current batch: 350
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 2.9943647384643555
#
# Current batch: 360
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.041231393814087
#
# Current batch: 370
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.095236301422119
#
# Current batch: 380
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.9023520946502686
#
# Current batch: 390
# Current adversarial train accuracy: 0.275
# Current adversarial train loss: 2.9062724113464355
#
# Total adversarial train accuarcy: 23.996
# Total adversarial train loss: 1197.604397058487
#
# [ Test epoch: 4 ]
#
# Current batch: 0
# Current benign test accuracy: 0.53
# Current benign test loss: 1.9711670875549316
# Current adversarial test accuracy: 0.27
# Current adversarial test loss: 3.072633981704712
#
# Current batch: 10
# Current benign test accuracy: 0.47
# Current benign test loss: 2.1400413513183594
# Current adversarial test accuracy: 0.18
# Current adversarial test loss: 3.3039541244506836
#
# Current batch: 20
# Current benign test accuracy: 0.48
# Current benign test loss: 2.2312347888946533
# Current adversarial test accuracy: 0.21
# Current adversarial test loss: 3.362980842590332
#
# Current batch: 30
# Current benign test accuracy: 0.46
# Current benign test loss: 2.2445337772369385
# Current adversarial test accuracy: 0.21
# Current adversarial test loss: 3.3486084938049316
#
# Current batch: 40
# Current benign test accuracy: 0.53
# Current benign test loss: 2.104933500289917
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.159592628479004
#
# Current batch: 50
# Current benign test accuracy: 0.52
# Current benign test loss: 2.0287282466888428
# Current adversarial test accuracy: 0.27
# Current adversarial test loss: 3.12376070022583
#
# Current batch: 60
# Current benign test accuracy: 0.51
# Current benign test loss: 2.0891377925872803
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.1793484687805176
#
# Current batch: 70
# Current benign test accuracy: 0.43
# Current benign test loss: 2.191577672958374
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.294036865234375
#
# Current batch: 80
# Current benign test accuracy: 0.44
# Current benign test loss: 2.3230338096618652
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 3.3949904441833496
#
# Current batch: 90
# Current benign test accuracy: 0.54
# Current benign test loss: 2.1676576137542725
# Current adversarial test accuracy: 0.21
# Current adversarial test loss: 3.22184419631958
#
# Total benign test accuarcy: 47.21
# Total adversarial test Accuarcy: 23.19
# Total benign test loss: 212.70470261573792
# Total adversarial test loss: 323.0030310153961
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 2.8628993034362793
#
# Current batch: 10
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.9249579906463623
#
# Current batch: 20
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.868217945098877
#
# Current batch: 30
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.7795677185058594
#
# Current batch: 40
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.9318220615386963
#
# Current batch: 50
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.970242977142334
#
# Current batch: 60
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 3.04512357711792
#
# Current batch: 70
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 2.993130922317505
#
# Current batch: 80
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.9735007286071777
#
# Current batch: 90
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.945739269256592
#
# Current batch: 100
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 2.8590927124023438
#
# Current batch: 110
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.832998752593994
#
# Current batch: 120
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 3.0729689598083496
#
# Current batch: 130
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.914811372756958
#
# Current batch: 140
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.85611891746521
#
# Current batch: 150
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 2.9973056316375732
#
# Current batch: 160
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.750502347946167
#
# Current batch: 170
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.705410957336426
#
# Current batch: 180
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.779449701309204
#
# Current batch: 190
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.9723620414733887
#
# Current batch: 200
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.5931031703948975
#
# Current batch: 210
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.886592149734497
#
# Current batch: 220
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.704347848892212
#
# Current batch: 230
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.7971787452697754
#
# Current batch: 240
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.8859262466430664
#
# Current batch: 250
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.692920207977295
#
# Current batch: 260
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.9153928756713867
#
# Current batch: 270
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.7652041912078857
#
# Current batch: 280
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.073068618774414
#
# Current batch: 290
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.768789529800415
#
# Current batch: 300
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.7464542388916016
#
# Current batch: 310
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.0684924125671387
#
# Current batch: 320
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.768888235092163
#
# Current batch: 330
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.840536594390869
#
# Current batch: 340
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.578303813934326
#
# Current batch: 350
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.748387336730957
#
# Current batch: 360
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 3.1437900066375732
#
# Current batch: 370
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.8250129222869873
#
# Current batch: 380
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 3.0588583946228027
#
# Current batch: 390
# Current adversarial train accuracy: 0.3375
# Current adversarial train loss: 2.6860876083374023
#
# Total adversarial train accuarcy: 27.948
# Total adversarial train loss: 1119.919983625412
#
# [ Test epoch: 5 ]
#
# Current batch: 0
# Current benign test accuracy: 0.55
# Current benign test loss: 1.9142898321151733
# Current adversarial test accuracy: 0.29
# Current adversarial test loss: 2.9691195487976074
#
# Current batch: 10
# Current benign test accuracy: 0.53
# Current benign test loss: 2.0244410037994385
# Current adversarial test accuracy: 0.2
# Current adversarial test loss: 3.14119029045105
#
# Current batch: 20
# Current benign test accuracy: 0.5
# Current benign test loss: 2.131225109100342
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 3.2125556468963623
#
# Current batch: 30
# Current benign test accuracy: 0.48
# Current benign test loss: 2.132050037384033
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.2044219970703125
#
# Current batch: 40
# Current benign test accuracy: 0.54
# Current benign test loss: 2.016676902770996
# Current adversarial test accuracy: 0.3
# Current adversarial test loss: 3.033656120300293
#
# Current batch: 50
# Current benign test accuracy: 0.57
# Current benign test loss: 1.9568246603012085
# Current adversarial test accuracy: 0.3
# Current adversarial test loss: 3.029768943786621
#
# Current batch: 60
# Current benign test accuracy: 0.53
# Current benign test loss: 1.9444870948791504
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 3.0081958770751953
#
# Current batch: 70
# Current benign test accuracy: 0.45
# Current benign test loss: 2.09104323387146
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.1760692596435547
#
# Current batch: 80
# Current benign test accuracy: 0.46
# Current benign test loss: 2.196920871734619
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 3.2617526054382324
#
# Current batch: 90
# Current benign test accuracy: 0.51
# Current benign test loss: 2.1324915885925293
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 3.144620895385742
#
# Total benign test accuarcy: 51.65
# Total adversarial test Accuarcy: 25.35
# Total benign test loss: 202.08777582645416
# Total adversarial test loss: 308.05113792419434
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.755509376525879
#
# Current batch: 10
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.7521817684173584
#
# Current batch: 20
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 2.679227113723755
#
# Current batch: 30
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 2.5851051807403564
#
# Current batch: 40
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 3.038045883178711
#
# Current batch: 50
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 2.5865702629089355
#
# Current batch: 60
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 3.165229082107544
#
# Current batch: 70
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.886385440826416
#
# Current batch: 80
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.8338186740875244
#
# Current batch: 90
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.6519432067871094
#
# Current batch: 100
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 2.5515198707580566
#
# Current batch: 110
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 2.66278338432312
#
# Current batch: 120
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 2.8547704219818115
#
# Current batch: 130
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.9089393615722656
#
# Current batch: 140
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.717667818069458
#
# Current batch: 150
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 3.0114362239837646
#
# Current batch: 160
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 2.7346270084381104
#
# Current batch: 170
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.7579874992370605
#
# Current batch: 180
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 2.717087507247925
#
# Current batch: 190
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 2.7983291149139404
#
# Current batch: 200
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.536792516708374
#
# Current batch: 210
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.7036402225494385
#
# Current batch: 220
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.574653387069702
#
# Current batch: 230
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.6467747688293457
#
# Current batch: 240
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.7648754119873047
#
# Current batch: 250
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.909006357192993
#
# Current batch: 260
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.5440187454223633
#
# Current batch: 270
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.87648606300354
#
# Current batch: 280
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.8679986000061035
#
# Current batch: 290
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 2.591454029083252
#
# Current batch: 300
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.711865186691284
#
# Current batch: 310
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 3.120151996612549
#
# Current batch: 320
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 2.825532913208008
#
# Current batch: 330
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.967827558517456
#
# Current batch: 340
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.8363535404205322
#
# Current batch: 350
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.9676101207733154
#
# Current batch: 360
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.6914126873016357
#
# Current batch: 370
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.710749626159668
#
# Current batch: 380
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.7751924991607666
#
# Current batch: 390
# Current adversarial train accuracy: 0.3375
# Current adversarial train loss: 2.6987030506134033
#
# Total adversarial train accuarcy: 29.75
# Total adversarial train loss: 1086.8086149692535
#
# [ Test epoch: 6 ]
#
# Current batch: 0
# Current benign test accuracy: 0.6
# Current benign test loss: 1.8605804443359375
# Current adversarial test accuracy: 0.3
# Current adversarial test loss: 2.965709924697876
#
# Current batch: 10
# Current benign test accuracy: 0.56
# Current benign test loss: 1.9700927734375
# Current adversarial test accuracy: 0.19
# Current adversarial test loss: 3.1338717937469482
#
# Current batch: 20
# Current benign test accuracy: 0.52
# Current benign test loss: 2.041529655456543
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.1493771076202393
#
# Current batch: 30
# Current benign test accuracy: 0.5
# Current benign test loss: 2.0390045642852783
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 3.148207902908325
#
# Current batch: 40
# Current benign test accuracy: 0.54
# Current benign test loss: 1.9756920337677002
# Current adversarial test accuracy: 0.31
# Current adversarial test loss: 3.036214590072632
#
# Current batch: 50
# Current benign test accuracy: 0.58
# Current benign test loss: 1.8828108310699463
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 2.9801697731018066
#
# Current batch: 60
# Current benign test accuracy: 0.56
# Current benign test loss: 1.8747974634170532
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 2.955472946166992
#
# Current batch: 70
# Current benign test accuracy: 0.48
# Current benign test loss: 1.9959053993225098
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.1167900562286377
#
# Current batch: 80
# Current benign test accuracy: 0.43
# Current benign test loss: 2.128249406814575
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.22927188873291
#
# Current batch: 90
# Current benign test accuracy: 0.55
# Current benign test loss: 2.0580942630767822
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 3.1053500175476074
#
# Total benign test accuarcy: 53.31
# Total adversarial test Accuarcy: 26.01
# Total benign test loss: 195.3436315059662
# Total adversarial test loss: 305.17012548446655
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.6948139667510986
#
# ...
#
# Current batch: 380
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 2.9890522956848145
#
# Current batch: 390
# Current adversarial train accuracy: 0.3
# Current adversarial train loss: 2.8154330253601074
#
# Total adversarial train accuarcy: 30.626
# Total adversarial train loss: 1073.4078352451324
#
# [ Test epoch: 7 ]
#
# Current batch: 0
# Current benign test accuracy: 0.59
# Current benign test loss: 1.8237251043319702
# Current adversarial test accuracy: 0.29
# Current adversarial test loss: 2.970912456512451
#
# Current batch: 10
# Current benign test accuracy: 0.58
# Current benign test loss: 1.9018090963363647
# Current adversarial test accuracy: 0.19
# Current adversarial test loss: 3.1271958351135254
#
# Current batch: 20
# Current benign test accuracy: 0.53
# Current benign test loss: 1.977545142173767
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.101681709289551
#
# Current batch: 30
# Current benign test accuracy: 0.5
# Current benign test loss: 1.973482608795166
# Current adversarial test accuracy: 0.22
# Current adversarial test loss: 3.1256275177001953
#
# Current batch: 40
# Current benign test accuracy: 0.56
# Current benign test loss: 1.887515664100647
# Current adversarial test accuracy: 0.3
# Current adversarial test loss: 3.0088062286376953
#
# Current batch: 50
# Current benign test accuracy: 0.58
# Current benign test loss: 1.8287529945373535
# Current adversarial test accuracy: 0.35
# Current adversarial test loss: 2.989565134048462
#
# Current batch: 60
# Current benign test accuracy: 0.54
# Current benign test loss: 1.8181672096252441
# Current adversarial test accuracy: 0.3
# Current adversarial test loss: 2.9198060035705566
#
# Current batch: 70
# Current benign test accuracy: 0.5
# Current benign test loss: 1.9304736852645874
# Current adversarial test accuracy: 0.28
# Current adversarial test loss: 3.098794937133789
#
# Current batch: 80
# Current benign test accuracy: 0.46
# Current benign test loss: 2.0571744441986084
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.2061779499053955
#
# Current batch: 90
# Current benign test accuracy: 0.55
# Current benign test loss: 1.9993188381195068
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.111959934234619
#
# Total benign test accuarcy: 54.61
# Total adversarial test Accuarcy: 25.81
# Total benign test loss: 189.72887921333313
# Total adversarial test loss: 304.5478901863098
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.6507365703582764
#
# Current batch: 10
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.9359076023101807
#
# Current batch: 20
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.8964667320251465
#
# Current batch: 30
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 3.0263516902923584
#
# Current batch: 40
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 2.710169553756714
#
# Current batch: 50
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.840251922607422
#
# Current batch: 60
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.9763553142547607
#
# Current batch: 70
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 2.7332513332366943
#
# Current batch: 80
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 2.8990602493286133
#
# Current batch: 90
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.5870325565338135
#
# Current batch: 100
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.8487660884857178
#
# Current batch: 110
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.7257392406463623
#
# Current batch: 120
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 2.4723260402679443
#
# Current batch: 130
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.772388219833374
#
# Current batch: 140
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.615769863128662
#
# Current batch: 150
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 2.5030019283294678
#
# Current batch: 160
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.758262872695923
#
# Current batch: 170
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.7091503143310547
#
# Current batch: 180
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.6985526084899902
#
# Current batch: 190
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.8642983436584473
#
# Current batch: 200
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.6577816009521484
#
# Current batch: 210
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 2.5432162284851074
#
# Current batch: 220
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.6292521953582764
#
# Current batch: 230
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 2.632634162902832
#
# Current batch: 240
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 2.6290528774261475
#
# Current batch: 250
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 2.4998416900634766
#
# Current batch: 260
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.5179803371429443
#
# Current batch: 270
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.7010345458984375
#
# Current batch: 280
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.5674309730529785
#
# Current batch: 290
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 2.8404579162597656
#
# Current batch: 300
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.889165163040161
#
# Current batch: 310
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 2.5023953914642334
#
# Current batch: 320
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.8067307472229004
#
# Current batch: 330
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.663015127182007
#
# Current batch: 340
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.740048885345459
#
# Current batch: 350
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.5691349506378174
#
# Current batch: 360
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.7796361446380615
#
# Current batch: 370
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.8609395027160645
#
# Current batch: 380
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.957824468612671
#
# Current batch: 390
# Current adversarial train accuracy: 0.3
# Current adversarial train loss: 2.566988706588745
#
# Total adversarial train accuarcy: 30.854
# Total adversarial train loss: 1062.9234199523926
#
# [ Test epoch: 8 ]
#
# Current batch: 0
# Current benign test accuracy: 0.58
# Current benign test loss: 1.8284565210342407
# Current adversarial test accuracy: 0.3
# Current adversarial test loss: 2.937596082687378
#
# Current batch: 10
# Current benign test accuracy: 0.57
# Current benign test loss: 1.9130148887634277
# Current adversarial test accuracy: 0.2
# Current adversarial test loss: 3.1102588176727295
#
# Current batch: 20
# Current benign test accuracy: 0.53
# Current benign test loss: 1.9925724267959595
# Current adversarial test accuracy: 0.27
# Current adversarial test loss: 3.0981085300445557
#
# Current batch: 30
# Current benign test accuracy: 0.49
# Current benign test loss: 1.9916963577270508
# Current adversarial test accuracy: 0.27
# Current adversarial test loss: 3.116204023361206
#
# Current batch: 40
# Current benign test accuracy: 0.57
# Current benign test loss: 1.9292336702346802
# Current adversarial test accuracy: 0.31
# Current adversarial test loss: 3.000046968460083
#
# Current batch: 50
# Current benign test accuracy: 0.58
# Current benign test loss: 1.8587031364440918
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 2.988201856613159
#
# Current batch: 60
# Current benign test accuracy: 0.53
# Current benign test loss: 1.8447990417480469
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 2.939368486404419
#
# Current batch: 70
# Current benign test accuracy: 0.54
# Current benign test loss: 1.9478274583816528
# Current adversarial test accuracy: 0.27
# Current adversarial test loss: 3.093907117843628
#
# Current batch: 80
# Current benign test accuracy: 0.47
# Current benign test loss: 2.089449167251587
# Current adversarial test accuracy: 0.27
# Current adversarial test loss: 3.2073378562927246
#
# Current batch: 90
# Current benign test accuracy: 0.54
# Current benign test loss: 2.0263047218322754
# Current adversarial test accuracy: 0.25
# Current adversarial test loss: 3.0959770679473877
#
# Total benign test accuarcy: 54.12
# Total adversarial test Accuarcy: 26.61
# Total benign test loss: 191.63171660900116
# Total adversarial test loss: 303.0192995071411
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 2.5053141117095947
#
# Current batch: 10
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.690502405166626
#
# Current batch: 20
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.8437397480010986
#
# Current batch: 30
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.8304572105407715
#
# Current batch: 40
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 2.6217756271362305
#
# Current batch: 50
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.821589231491089
#
# Current batch: 60
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.8961985111236572
#
# Current batch: 70
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.681591272354126
#
# Current batch: 80
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 2.9702274799346924
#
# Current batch: 90
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.76851749420166
#
# Current batch: 100
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.861166000366211
#
# Current batch: 110
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.620370388031006
#
# Current batch: 120
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.7455265522003174
#
# Current batch: 130
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 2.6073806285858154
#
# Current batch: 140
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.710949182510376
#
# Current batch: 150
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.7849833965301514
#
# Current batch: 160
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 2.9135448932647705
#
# Current batch: 170
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.609774112701416
#
# Current batch: 180
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.6810662746429443
#
# Current batch: 190
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.530316114425659
#
# Current batch: 200
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 2.7346227169036865
#
# Current batch: 210
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 2.6321756839752197
#
# Current batch: 220
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 2.8657703399658203
#
# Current batch: 230
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.6094491481781006
#
# Current batch: 240
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 2.632321357727051
#
# Current batch: 250
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 2.7618560791015625
#
# Current batch: 260
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.702868700027466
#
# Current batch: 270
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.6017446517944336
#
# Current batch: 280
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 2.681539535522461
#
# Current batch: 290
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.7087128162384033
#
# Current batch: 300
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 2.767676830291748
#
# Current batch: 310
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 2.6078367233276367
#
# Current batch: 320
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.7503626346588135
#
# Current batch: 330
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 2.710522174835205
#
# Current batch: 340
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.9040658473968506
#
# Current batch: 350
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.7395336627960205
#
# Current batch: 360
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.751403331756592
#
# Current batch: 370
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 2.5202431678771973
#
# Current batch: 380
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 2.655738592147827
#
# Current batch: 390
# Current adversarial train accuracy: 0.275
# Current adversarial train loss: 2.7507102489471436
#
# Total adversarial train accuarcy: 31.11
# Total adversarial train loss: 1055.39004445076
#
# [ Test epoch: 9 ]
#
# Current batch: 0
# Current benign test accuracy: 0.6
# Current benign test loss: 1.810062289237976
# Current adversarial test accuracy: 0.31
# Current adversarial test loss: 2.9203732013702393
#
# Current batch: 10
# Current benign test accuracy: 0.57
# Current benign test loss: 1.9118915796279907
# Current adversarial test accuracy: 0.23
# Current adversarial test loss: 3.127825975418091
#
# Current batch: 20
# Current benign test accuracy: 0.53
# Current benign test loss: 2.0010979175567627
# Current adversarial test accuracy: 0.28
# Current adversarial test loss: 3.12603759765625
#
# Current batch: 30
# Current benign test accuracy: 0.48
# Current benign test loss: 1.9870555400848389
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.113865852355957
#
# Current batch: 40
# Current benign test accuracy: 0.55
# Current benign test loss: 1.9457505941390991
# Current adversarial test accuracy: 0.29
# Current adversarial test loss: 3.0333194732666016
#
# Current batch: 50
# Current benign test accuracy: 0.57
# Current benign test loss: 1.8626171350479126
# Current adversarial test accuracy: 0.34
# Current adversarial test loss: 3.0141055583953857
#
# Current batch: 60
# Current benign test accuracy: 0.53
# Current benign test loss: 1.8472071886062622
# Current adversarial test accuracy: 0.28
# Current adversarial test loss: 2.9686923027038574
#
# Current batch: 70
# Current benign test accuracy: 0.52
# Current benign test loss: 1.9691694974899292
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.131748914718628
#
# Current batch: 80
# Current benign test accuracy: 0.47
# Current benign test loss: 2.085824966430664
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 3.217069387435913
#
# Current batch: 90
# Current benign test accuracy: 0.53
# Current benign test loss: 2.0495948791503906
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 3.131406545639038
#
# Total benign test accuarcy: 54.51
# Total adversarial test Accuarcy: 26.21
# Total benign test loss: 190.87753796577454
# Total adversarial test loss: 303.5230088233948
# Model Saved!

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion * planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])
def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
net = ResNet18()
net = net.to(device)
cudnn.benchmark = True
checkpoint = torch.load('./checkpoint/' + file_name)
net.load_state_dict(checkpoint['net'])
# Out:
# <All keys matched successfully>

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
])
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
test_loader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
l = [x for (x, y) in test_loader]
x_test = torch.cat(l, 0)
l = [y for (x, y) in test_loader]
y_test = torch.cat(l, 0)
# Out:
# Files already downloaded and verified

# %%
def eval_test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, size_average=False).item()
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    print('Test: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    test_accuracy = correct / len(test_loader.dataset)
    return test_loss, test_accuracy
eval_test(net, device, test_loader)
# Out:
# Test: Average loss: 1.9088, Accuracy: 5451/10000 (55%)
# (1.9087753829956056, 0.5451)

# %%
# !pip install git+https://github.com/fra31/auto-attack
# Out:
# Collecting git+https://github.com/fra31/auto-attack
#   Cloning https://github.com/fra31/auto-attack to c:\users\zahra\appdata\local\temp\pip-req-build-zrzul4jy
#   Resolved https://github.com/fra31/auto-attack to commit a39220048b3c9f2cca9a4d3a54604793c68eca7e
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Running command git clone --filter=blob:none --quiet https://github.com/fra31/auto-attack 'C:\Users\zahra\AppData\Local\Temp\pip-req-build-zrzul4jy'

# %%
from autoattack import AutoAttack
adversary = AutoAttack(net, norm='Linf', eps=0.031, version='standard')
# Out:
# setting parameters for standard version

# %%
adv_complete = adversary.run_standard_evaluation(x_test, y_test,bs=500)
# Out:
# using standard version including apgd-ce, apgd-t, fab-t, square.
# initial accuracy: 54.51%
# apgd-ce - 1/11 - 252 out of 500 successfully perturbed
# apgd-ce - 2/11 - 291 out of 500 successfully perturbed
# apgd-ce - 3/11 - 264 out of 500 successfully perturbed
# apgd-ce - 4/11 - 269 out of 500 successfully perturbed
# apgd-ce - 5/11 - 266 out of 500 successfully perturbed
# apgd-ce - 6/11 - 281 out of 500 successfully perturbed
# apgd-ce - 7/11 - 289 out of 500 successfully perturbed
# apgd-ce - 8/11 - 280 out of 500 successfully perturbed
# apgd-ce - 9/11 - 271 out of 500 successfully perturbed
# apgd-ce - 10/11 - 283 out of 500 successfully perturbed
# apgd-ce - 11/11 - 245 out of 451 successfully perturbed
# robust accuracy after APGD-CE: 24.60% (total time 138.4 s)
# apgd-t - 1/5 - 68 out of 500 successfully perturbed
# apgd-t - 2/5 - 83 out of 500 successfully perturbed
# apgd-t - 3/5 - 90 out of 500 successfully perturbed
# apgd-t - 4/5 - 94 out of 500 successfully perturbed
# apgd-t - 5/5 - 74 out of 460 successfully perturbed
# robust accuracy after APGD-T: 20.51% (total time 671.4 s)
# fab-t - 1/5 - 0 out of 500 successfully perturbed
# fab-t - 2/5 - 0 out of 500 successfully perturbed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 adv_complete = adversary.run_standard_evaluation(x_test, y_test,bs=500)
#
# File ~\anaconda3\lib\site-packages\autoattack\autoattack.py:216, in AutoAttack.run_standard_evaluation(self, x_orig, y_orig, bs, return_labels, state_path)
#     214     self.fab.n_restarts = 1
#     215     self.fab.seed = self.get_seed()
# --> 216     adv_curr = self.fab.perturb(x, y)
#     218 else:
#     219     raise ValueError('Attack not supported')
#
# File ~\anaconda3\lib\site-packages\autoattack\fab_base.py:310, in FABAttack.perturb(self, x, y)
#     308 if ind_to_fool.numel() != 0:
#     309     x_to_fool, y_to_fool = x[ind_to_fool].clone(), y[ind_to_fool].clone()
# --> 310     adv_curr = self.attack_single_run(x_to_fool, y_to_fool, use_rand_start=(counter > 0), is_targeted=True)
#     312     acc_curr = self._predict_fn(adv_curr).max(1)[1] == y_to_fool
#     313     if self.norm == 'Linf':
#
# File ~\anaconda3\lib\site-packages\autoattack\fab_base.py:186, in FABAttack.attack_single_run(self, x, y, use_rand_start, is_targeted)
#     184 ind = dist1.min(dim=1)[1]
#     185 dg2 = dg[u1, ind]
# --> 186 b = (- df[u1, ind] + (dg2 * x1).reshape(x1.shape[0], -1)
#     187                         .sum(dim=-1))
#     188 w = dg2.reshape([bs, -1])
#     190 if self.norm == 'Linf':
#
# KeyboardInterrupt:

# %%
adv_loader_Linf = torch.utils.data.DataLoader(adv_complete, batch_size=100, shuffle=False, num_workers=2)
num_total_images = 0
num_successful_attacks = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
    for adv_images in adv_loader_Linf:
        adv_images = adv_images.to(device)
        outputs_adv = net(adv_images)
        _, predicted_adv = torch.max(outputs_adv.data, 1)

        # Count the number of adversarial examples that were successfully attacked
        for i in range(len(images)):
            if predicted[i] != predicted_adv[i]:
                num_successful_attacks += 1
        
        # Increment the total number of images
        num_total_images += len(images)

# Calculate the adversarial attack rate
attack_rate = (num_successful_attacks / num_total_images) * 100
print(f"Adversarial attack rate: {attack_rate:.2f}%")

# %%
from autoattack import AutoAttack
adversary_L2 = AutoAttack(net, norm='L2', eps=0.031, version='standard')
adv_complete_L2 = adversary_L2.run_standard_evaluation(x_test, y_test,bs=500)

# %%
adv_loader_L2 = torch.utils.data.DataLoader(adv_complete_L2, batch_size=100, shuffle=False, num_workers=2)
num_total_images = 0
num_successful_attacks = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
    for adv_images in adv_loader_L2:
        adv_images = adv_images.to(device)
        outputs_adv = net(adv_images)
        _, predicted_adv = torch.max(outputs_adv.data, 1)

        # Count the number of adversarial examples that were successfully attacked
        for i in range(len(images)):
            if predicted[i] != predicted_adv[i]:
                num_successful_attacks += 1
        
        # Increment the total number of images
        num_total_images += len(images)

# Calculate the adversarial attack rate
attack_rate = (num_successful_attacks / num_total_images) * 100
print(f"Adversarial attack rate: {attack_rate:.2f}%")
