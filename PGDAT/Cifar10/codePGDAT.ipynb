# %%
from __future__ import print_function
import os
import argparse
import sys
sys.argv
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from torchvision import datasets, transforms
import random
import numpy as np
SEED=1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.benchmark = False
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion * planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])
def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
if not os.path.exists('model-resnet-epoch76.pt'):
    os.makedirs('model-resnet-epoch76.pt')
use_cuda = not False and torch.cuda.is_available()
torch.manual_seed(1)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
net=ResNet18()
net.load_state_dict(torch.load('model-resnet-epoch76.pt'))
net.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=100, bias=True)
# )

# %%
#PGD_adversarial_training
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import os

#from models import *

learning_rate = 0.1
epsilon = 0.0314
k = 7
alpha = 0.00784
file_name = 'pgd_adversarial_training'

device = 'cuda' if torch.cuda.is_available() else 'cpu'

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)

class LinfPGDAttack(object):
    def __init__(self, model):
        self.model = model

    def perturb(self, x_natural, y):
        x = x_natural.detach()
        x = x + torch.zeros_like(x).uniform_(-epsilon, epsilon)
        for i in range(k):
            x.requires_grad_()
            with torch.enable_grad():
                logits = self.model(x)
                loss = F.cross_entropy(logits, y)
            grad = torch.autograd.grad(loss, [x])[0]
            x = x.detach() + alpha * torch.sign(grad.detach())
            x = torch.min(torch.max(x, x_natural - epsilon), x_natural + epsilon)
            x = torch.clamp(x, 0, 1)
        return x

def attack(x, y, model, adversary):
    model_copied = copy.deepcopy(model)
    model_copied.eval()
    adversary.model = model_copied
    adv = adversary.perturb(x, y)
    return adv


adversary = LinfPGDAttack(net)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        adv = adversary.perturb(inputs, targets)
        adv_outputs = net(adv)
        loss = criterion(adv_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = adv_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 10 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current adversarial train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current adversarial train loss:', loss.item())

    print('\nTotal adversarial train accuarcy:', 100. * correct / total)
    print('Total adversarial train loss:', train_loss)

def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    benign_loss = 0
    adv_loss = 0
    benign_correct = 0
    adv_correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            total += targets.size(0)

            outputs = net(inputs)
            loss = criterion(outputs, targets)
            benign_loss += loss.item()

            _, predicted = outputs.max(1)
            benign_correct += predicted.eq(targets).sum().item()

            if batch_idx % 10 == 0:
                print('\nCurrent batch:', str(batch_idx))
                print('Current benign test accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
                print('Current benign test loss:', loss.item())

            adv = adversary.perturb(inputs, targets)
            adv_outputs = net(adv)
            loss = criterion(adv_outputs, targets)
            adv_loss += loss.item()

            _, predicted = adv_outputs.max(1)
            adv_correct += predicted.eq(targets).sum().item()

            if batch_idx % 10 == 0:
                print('Current adversarial test accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
                print('Current adversarial test loss:', loss.item())

    print('\nTotal benign test accuarcy:', 100. * benign_correct / total)
    print('Total adversarial test Accuarcy:', 100. * adv_correct / total)
    print('Total benign test loss:', benign_loss)
    print('Total adversarial test loss:', adv_loss)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 32:
        lr /= 10
    if epoch >= 50:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

for epoch in range(0, 75):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.0
# Current adversarial train loss: 14.826066970825195
#
# Current batch: 10
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 2.9605836868286133
#
# Current batch: 20
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 2.3775501251220703
#
# Current batch: 30
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 2.195331335067749
#
# Current batch: 40
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 2.1347334384918213
#
# Current batch: 50
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 2.0677363872528076
#
# Current batch: 60
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 2.0533132553100586
#
# Current batch: 70
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 1.9390214681625366
#
# Current batch: 80
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 2.1041765213012695
#
# Current batch: 90
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 2.016385316848755
#
# Current batch: 100
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.0142502784729004
#
# Current batch: 110
# Current adversarial train accuracy: 0.21875
# Current adversarial train loss: 2.0395007133483887
#
# Current batch: 120
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.0320322513580322
#
# Current batch: 130
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 1.9330394268035889
#
# Current batch: 140
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 1.8992499113082886
#
# Current batch: 150
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 1.9175611734390259
#
# Current batch: 160
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.096599578857422
#
# Current batch: 170
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 1.9848265647888184
#
# Current batch: 180
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 1.797985315322876
#
# Current batch: 190
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 1.8741470575332642
#
# Current batch: 200
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 2.001218557357788
#
# Current batch: 210
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 1.8571349382400513
#
# Current batch: 220
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 1.8910611867904663
#
# Current batch: 230
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 1.8161242008209229
#
# Current batch: 240
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 1.8145115375518799
#
# Current batch: 250
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 1.8026888370513916
#
# Current batch: 260
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 1.8848093748092651
#
# Current batch: 270
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 1.865865707397461
#
# Current batch: 280
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 1.754973292350769
#
# Current batch: 290
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.8347454071044922
#
# Current batch: 300
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 1.9179701805114746
#
# Current batch: 310
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 1.816571593284607
#
# Current batch: 320
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.8597272634506226
#
# Current batch: 330
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 1.8449749946594238
#
# Current batch: 340
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.754745602607727
#
# Current batch: 350
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.767770767211914
#
# Current batch: 360
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.6190822124481201
#
# Current batch: 370
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 1.7454417943954468
#
# Current batch: 380
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.5742911100387573
#
# Current batch: 390
# Current adversarial train accuracy: 0.4
# Current adversarial train loss: 1.477655053138733
#
# Total adversarial train accuarcy: 26.81
# Total adversarial train loss: 804.2103550434113
#
# [ Test epoch: 0 ]
#
# Current batch: 0
# Current benign test accuracy: 0.65
# Current benign test loss: 1.140610933303833
# Current adversarial test accuracy: 0.38
# Current adversarial test loss: 1.6643763780593872
#
# Current batch: 10
# Current benign test accuracy: 0.62
# Current benign test loss: 1.2224599123001099
# Current adversarial test accuracy: 0.4
# Current adversarial test loss: 1.7629379034042358
#
# Current batch: 20
# Current benign test accuracy: 0.62
# Current benign test loss: 1.1421501636505127
# Current adversarial test accuracy: 0.35
# Current adversarial test loss: 1.6034904718399048
#
# Current batch: 30
# Current benign test accuracy: 0.65
# Current benign test loss: 1.1037302017211914
# Current adversarial test accuracy: 0.36
# Current adversarial test loss: 1.6134170293807983
#
# Current batch: 40
# Current benign test accuracy: 0.67
# Current benign test loss: 1.176012396812439
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 1.7349746227264404
#
# Current batch: 50
# Current benign test accuracy: 0.64
# Current benign test loss: 1.1475870609283447
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 1.726010799407959
#
# Current batch: 60
# Current benign test accuracy: 0.6
# Current benign test loss: 1.2091689109802246
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 1.7042981386184692
#
# Current batch: 70
# Current benign test accuracy: 0.58
# Current benign test loss: 1.178320050239563
# Current adversarial test accuracy: 0.33
# Current adversarial test loss: 1.762925148010254
#
# Current batch: 80
# Current benign test accuracy: 0.64
# Current benign test loss: 1.1475948095321655
# Current adversarial test accuracy: 0.33
# Current adversarial test loss: 1.7035820484161377
#
# Current batch: 90
# Current benign test accuracy: 0.68
# Current benign test loss: 1.0690975189208984
# Current adversarial test accuracy: 0.3
# Current adversarial test loss: 1.6268222332000732
#
# Total benign test accuarcy: 62.01
# Total adversarial test Accuarcy: 35.61
# Total benign test loss: 116.23075532913208
# Total adversarial test loss: 169.55334305763245
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.6683189868927002
#
# Current batch: 10
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 1.6978973150253296
#
# Current batch: 20
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 1.6771024465560913
#
# Current batch: 30
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 1.6494659185409546
#
# Current batch: 40
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 1.7325376272201538
#
# Current batch: 50
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 1.7321430444717407
#
# Current batch: 60
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.4845207929611206
#
# Current batch: 70
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 1.696577787399292
#
# Current batch: 80
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 1.6665058135986328
#
# Current batch: 90
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 1.6771810054779053
#
# Current batch: 100
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.635752558708191
#
# Current batch: 110
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.5393017530441284
#
# Current batch: 120
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.6007617712020874
#
# Current batch: 130
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 1.6564631462097168
#
# Current batch: 140
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 1.675262689590454
#
# Current batch: 150
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.5178568363189697
#
# Current batch: 160
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.7175410985946655
#
# Current batch: 170
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 1.649200439453125
#
# Current batch: 180
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 1.731567621231079
#
# Current batch: 190
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.7056267261505127
#
# Current batch: 200
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 1.6258962154388428
#
# Current batch: 210
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.5373964309692383
#
# Current batch: 220
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.770193099975586
#
# Current batch: 230
# Current adversarial train accuracy: 0.4765625
# Current adversarial train loss: 1.4169930219650269
#
# Current batch: 240
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 1.6733596324920654
#
# Current batch: 250
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.6222153902053833
#
# Current batch: 260
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.5844215154647827
#
# Current batch: 270
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.6147141456604004
#
# Current batch: 280
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.5115747451782227
#
# Current batch: 290
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.5643061399459839
#
# Current batch: 300
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.5180552005767822
#
# Current batch: 310
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.4915459156036377
#
# Current batch: 320
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 1.6591498851776123
#
# Current batch: 330
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.7591556310653687
#
# Current batch: 340
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 1.7853988409042358
#
# Current batch: 350
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.6680102348327637
#
# Current batch: 360
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.5290687084197998
#
# Current batch: 370
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.6070038080215454
#
# Current batch: 380
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.4037340879440308
#
# Current batch: 390
# Current adversarial train accuracy: 0.3375
# Current adversarial train loss: 1.5593374967575073
#
# Total adversarial train accuarcy: 37.066
# Total adversarial train loss: 642.5516781806946
#
# [ Test epoch: 1 ]
#
# Current batch: 0
# Current benign test accuracy: 0.74
# Current benign test loss: 1.007066011428833
# Current adversarial test accuracy: 0.31
# Current adversarial test loss: 1.5987588167190552
#
# Current batch: 10
# Current benign test accuracy: 0.71
# Current benign test loss: 0.9843200445175171
# Current adversarial test accuracy: 0.43
# Current adversarial test loss: 1.568894624710083
#
# Current batch: 20
# Current benign test accuracy: 0.61
# Current benign test loss: 1.0063623189926147
# Current adversarial test accuracy: 0.39
# Current adversarial test loss: 1.5230501890182495
#
# Current batch: 30
# Current benign test accuracy: 0.75
# Current benign test loss: 0.9578325748443604
# Current adversarial test accuracy: 0.4
# Current adversarial test loss: 1.4992318153381348
#
# Current batch: 40
# Current benign test accuracy: 0.74
# Current benign test loss: 0.9849785566329956
# Current adversarial test accuracy: 0.48
# Current adversarial test loss: 1.5631952285766602
#
# Current batch: 50
# Current benign test accuracy: 0.68
# Current benign test loss: 1.042001485824585
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 1.6878728866577148
#
# Current batch: 60
# Current benign test accuracy: 0.67
# Current benign test loss: 1.0429635047912598
# Current adversarial test accuracy: 0.37
# Current adversarial test loss: 1.5943763256072998
#
# Current batch: 70
# Current benign test accuracy: 0.66
# Current benign test loss: 0.971622109413147
# Current adversarial test accuracy: 0.41
# Current adversarial test loss: 1.5988709926605225
#
# Current batch: 80
# Current benign test accuracy: 0.67
# Current benign test loss: 0.9923524260520935
# Current adversarial test accuracy: 0.38
# Current adversarial test loss: 1.6052639484405518
#
# Current batch: 90
# Current benign test accuracy: 0.67
# Current benign test loss: 0.9653173089027405
# Current adversarial test accuracy: 0.39
# Current adversarial test loss: 1.5647114515304565
#
# Total benign test accuarcy: 68.63
# Total adversarial test Accuarcy: 40.19
# Total benign test loss: 98.69158160686493
# Total adversarial test loss: 156.80533063411713
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 1.624144434928894
#
# Current batch: 10
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 1.6130988597869873
#
# Current batch: 20
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.59163498878479
#
# Current batch: 30
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.5798044204711914
#
# Current batch: 40
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.5756996870040894
#
# Current batch: 50
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.428427815437317
#
# Current batch: 60
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 1.5391919612884521
#
# Current batch: 70
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.5333962440490723
#
# Current batch: 80
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.544008493423462
#
# Current batch: 90
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.4686789512634277
#
# Current batch: 100
# Current adversarial train accuracy: 0.4765625
# Current adversarial train loss: 1.3741041421890259
#
# Current batch: 110
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.5707075595855713
#
# Current batch: 120
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.5129640102386475
#
# Current batch: 130
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.5927438735961914
#
# Current batch: 140
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.5112223625183105
#
# Current batch: 150
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.5002144575119019
#
# Current batch: 160
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.5935695171356201
#
# Current batch: 170
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.5241012573242188
#
# Current batch: 180
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.500685691833496
#
# Current batch: 190
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 1.6686103343963623
#
# Current batch: 200
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4643073081970215
#
# Current batch: 210
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.579650640487671
#
# Current batch: 220
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.5942717790603638
#
# Current batch: 230
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4992485046386719
#
# Current batch: 240
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 1.6655218601226807
#
# Current batch: 250
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.5860114097595215
#
# Current batch: 260
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 1.6551703214645386
#
# Current batch: 270
# Current adversarial train accuracy: 0.4921875
# Current adversarial train loss: 1.4461883306503296
#
# Current batch: 280
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4500665664672852
#
# Current batch: 290
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.5839098691940308
#
# Current batch: 300
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.5466039180755615
#
# Current batch: 310
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.4440358877182007
#
# Current batch: 320
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.466596245765686
#
# Current batch: 330
# Current adversarial train accuracy: 0.4453125
# Current adversarial train loss: 1.4615603685379028
#
# Current batch: 340
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4590215682983398
#
# Current batch: 350
# Current adversarial train accuracy: 0.5078125
# Current adversarial train loss: 1.3621175289154053
#
# Current batch: 360
# Current adversarial train accuracy: 0.4453125
# Current adversarial train loss: 1.5613268613815308
#
# Current batch: 370
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.61232590675354
#
# Current batch: 380
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.5842584371566772
#
# Current batch: 390
# Current adversarial train accuracy: 0.3875
# Current adversarial train loss: 1.5463969707489014
#
# Total adversarial train accuarcy: 41.21
# Total adversarial train loss: 603.0455025434494
#
# [ Test epoch: 2 ]
#
# Current batch: 0
# Current benign test accuracy: 0.76
# Current benign test loss: 0.9168305993080139
# Current adversarial test accuracy: 0.39
# Current adversarial test loss: 1.5743833780288696
#
# Current batch: 10
# Current benign test accuracy: 0.77
# Current benign test loss: 0.9585931301116943
# Current adversarial test accuracy: 0.43
# Current adversarial test loss: 1.6353793144226074
#
# Current batch: 20
# Current benign test accuracy: 0.65
# Current benign test loss: 0.9280003309249878
# Current adversarial test accuracy: 0.37
# Current adversarial test loss: 1.4911693334579468
#
# Current batch: 30
# Current benign test accuracy: 0.73
# Current benign test loss: 0.9234268069267273
# Current adversarial test accuracy: 0.43
# Current adversarial test loss: 1.5219054222106934
#
# Current batch: 40
# Current benign test accuracy: 0.72
# Current benign test loss: 0.9666160345077515
# Current adversarial test accuracy: 0.39
# Current adversarial test loss: 1.6469497680664062
#
# Current batch: 50
# Current benign test accuracy: 0.76
# Current benign test loss: 0.9497801065444946
# Current adversarial test accuracy: 0.39
# Current adversarial test loss: 1.6466012001037598
#
# Current batch: 60
# Current benign test accuracy: 0.69
# Current benign test loss: 0.9486238956451416
# Current adversarial test accuracy: 0.38
# Current adversarial test loss: 1.5252737998962402
#
# Current batch: 70
# Current benign test accuracy: 0.68
# Current benign test loss: 0.918132483959198
# Current adversarial test accuracy: 0.44
# Current adversarial test loss: 1.5997588634490967
#
# Current batch: 80
# Current benign test accuracy: 0.73
# Current benign test loss: 0.904487133026123
# Current adversarial test accuracy: 0.4
# Current adversarial test loss: 1.5760765075683594
#
# Current batch: 90
# Current benign test accuracy: 0.76
# Current benign test loss: 0.8587530255317688
# Current adversarial test accuracy: 0.41
# Current adversarial test loss: 1.4654796123504639
#
# Total benign test accuarcy: 70.63
# Total adversarial test Accuarcy: 40.2
# Total benign test loss: 92.93366539478302
# Total adversarial test loss: 157.16476368904114
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.4609375
# Current adversarial train loss: 1.2708308696746826
#
# Current batch: 10
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 1.6325414180755615
#
# Current batch: 20
# Current adversarial train accuracy: 0.4609375
# Current adversarial train loss: 1.5229064226150513
#
# Current batch: 30
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.599777102470398
#
# Current batch: 40
# Current adversarial train accuracy: 0.4921875
# Current adversarial train loss: 1.3727518320083618
#
# Current batch: 50
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4659638404846191
#
# Current batch: 60
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.6053961515426636
#
# Current batch: 70
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.5729620456695557
#
# Current batch: 80
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.4334917068481445
#
# Current batch: 90
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4391578435897827
#
# Current batch: 100
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 1.4770934581756592
#
# Current batch: 110
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.5333744287490845
#
# Current batch: 120
# Current adversarial train accuracy: 0.4921875
# Current adversarial train loss: 1.4002630710601807
#
# Current batch: 130
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 1.529990315437317
#
# Current batch: 140
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4466633796691895
#
# Current batch: 150
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.547605037689209
#
# Current batch: 160
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.4733422994613647
#
# Current batch: 170
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.5429997444152832
#
# Current batch: 180
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.4682461023330688
#
# Current batch: 190
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4845163822174072
#
# Current batch: 200
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4021270275115967
#
# Current batch: 210
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.370805025100708
#
# Current batch: 220
# Current adversarial train accuracy: 0.5546875
# Current adversarial train loss: 1.2949374914169312
#
# Current batch: 230
# Current adversarial train accuracy: 0.5078125
# Current adversarial train loss: 1.4735124111175537
#
# Current batch: 240
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.7054736614227295
#
# Current batch: 250
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.5851942300796509
#
# Current batch: 260
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4159002304077148
#
# Current batch: 270
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.54411780834198
#
# Current batch: 280
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.465318202972412
#
# Current batch: 290
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.5469130277633667
#
# Current batch: 300
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.3801748752593994
#
# Current batch: 310
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.4288387298583984
#
# Current batch: 320
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.5274691581726074
#
# Current batch: 330
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.5880687236785889
#
# Current batch: 340
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.336411476135254
#
# Current batch: 350
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.38505220413208
#
# Current batch: 360
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.5927371978759766
#
# Current batch: 370
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.4346145391464233
#
# Current batch: 380
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.506659984588623
#
# Current batch: 390
# Current adversarial train accuracy: 0.475
# Current adversarial train loss: 1.4301975965499878
#
# Total adversarial train accuarcy: 42.912
# Total adversarial train loss: 580.6116251945496
#
# [ Test epoch: 3 ]
#
# Current batch: 0
# Current benign test accuracy: 0.77
# Current benign test loss: 0.9017285704612732
# Current adversarial test accuracy: 0.44
# Current adversarial test loss: 1.4770972728729248
#
# Current batch: 10
# Current benign test accuracy: 0.76
# Current benign test loss: 0.8827419281005859
# Current adversarial test accuracy: 0.49
# Current adversarial test loss: 1.4761735200881958
#
# Current batch: 20
# Current benign test accuracy: 0.66
# Current benign test loss: 0.9445416927337646
# Current adversarial test accuracy: 0.39
# Current adversarial test loss: 1.4649379253387451
#
# Current batch: 30
# Current benign test accuracy: 0.71
# Current benign test loss: 0.8960598111152649
# Current adversarial test accuracy: 0.46
# Current adversarial test loss: 1.4011274576187134
#
# Current batch: 40
# Current benign test accuracy: 0.74
# Current benign test loss: 0.93755704164505
# Current adversarial test accuracy: 0.45
# Current adversarial test loss: 1.5553803443908691
#
# Current batch: 50
# Current benign test accuracy: 0.7
# Current benign test loss: 0.9339569211006165
# Current adversarial test accuracy: 0.47
# Current adversarial test loss: 1.5686240196228027
#
# Current batch: 60
# Current benign test accuracy: 0.66
# Current benign test loss: 0.9864192008972168
# Current adversarial test accuracy: 0.38
# Current adversarial test loss: 1.5223814249038696
#
# Current batch: 70
# Current benign test accuracy: 0.63
# Current benign test loss: 0.9101200103759766
# Current adversarial test accuracy: 0.45
# Current adversarial test loss: 1.5288630723953247
#
# Current batch: 80
# Current benign test accuracy: 0.68
# Current benign test loss: 0.9573480486869812
# Current adversarial test accuracy: 0.39
# Current adversarial test loss: 1.561790943145752
#
# Current batch: 90
# Current benign test accuracy: 0.69
# Current benign test loss: 0.9026623368263245
# Current adversarial test accuracy: 0.37
# Current adversarial test loss: 1.484087347984314
#
# Total benign test accuarcy: 70.32
# Total adversarial test Accuarcy: 41.64
# Total benign test loss: 93.00386428833008
# Total adversarial test loss: 152.0234876871109
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.515625
# Current adversarial train loss: 1.3100340366363525
#
# Current batch: 10
# Current adversarial train accuracy: 0.515625
# Current adversarial train loss: 1.2486963272094727
#
# Current batch: 20
# Current adversarial train accuracy: 0.4765625
# Current adversarial train loss: 1.3701012134552002
#
# Current batch: 30
# Current adversarial train accuracy: 0.515625
# Current adversarial train loss: 1.3006064891815186
#
# Current batch: 40
# Current adversarial train accuracy: 0.4453125
# Current adversarial train loss: 1.4402203559875488
#
# Current batch: 50
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.4634904861450195
#
# Current batch: 60
# Current adversarial train accuracy: 0.5390625
# Current adversarial train loss: 1.3718576431274414
#
# Current batch: 70
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.3329110145568848
#
# Current batch: 80
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 1.5207008123397827
#
# Current batch: 90
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4267736673355103
#
# Current batch: 100
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.409349799156189
#
# Current batch: 110
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.3672959804534912
#
# Current batch: 120
# Current adversarial train accuracy: 0.515625
# Current adversarial train loss: 1.295357346534729
#
# Current batch: 130
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.4755898714065552
#
# Current batch: 140
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.5049059391021729
#
# Current batch: 150
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.4559627771377563
#
# Current batch: 160
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4644595384597778
#
# Current batch: 170
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4594759941101074
#
# Current batch: 180
# Current adversarial train accuracy: 0.5390625
# Current adversarial train loss: 1.2274850606918335
#
# Current batch: 190
# Current adversarial train accuracy: 0.5
# Current adversarial train loss: 1.37514066696167
#
# Current batch: 200
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.4168624877929688
#
# Current batch: 210
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.3660708665847778
#
# Current batch: 220
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 1.5202059745788574
#
# Current batch: 230
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.4489507675170898
#
# Current batch: 240
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4971880912780762
#
# Current batch: 250
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.3617615699768066
#
# Current batch: 260
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.507728099822998
#
# Current batch: 270
# Current adversarial train accuracy: 0.4453125
# Current adversarial train loss: 1.4761656522750854
#
# Current batch: 280
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 1.6332249641418457
#
# Current batch: 290
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.4513463973999023
#
# Current batch: 300
# Current adversarial train accuracy: 0.5078125
# Current adversarial train loss: 1.3630098104476929
#
# Current batch: 310
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 1.6192491054534912
#
# Current batch: 320
# Current adversarial train accuracy: 0.5
# Current adversarial train loss: 1.3151205778121948
#
# Current batch: 330
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.434746503829956
#
# Current batch: 340
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.586978793144226
#
# Current batch: 350
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.601921796798706
#
# Current batch: 360
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.4660195112228394
#
# Current batch: 370
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.5339546203613281
#
# Current batch: 380
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.4306927919387817
#
# Current batch: 390
# Current adversarial train accuracy: 0.425
# Current adversarial train loss: 1.3267943859100342
#
# Total adversarial train accuarcy: 44.242
# Total adversarial train loss: 564.8570923805237
#
# [ Test epoch: 4 ]
#
# Current batch: 0
# Current benign test accuracy: 0.73
# Current benign test loss: 0.8740169405937195
# Current adversarial test accuracy: 0.43
# Current adversarial test loss: 1.4728256464004517
#
# Current batch: 10
# Current benign test accuracy: 0.7
# Current benign test loss: 0.8699085712432861
# Current adversarial test accuracy: 0.51
# Current adversarial test loss: 1.543302059173584
#
# Current batch: 20
# Current benign test accuracy: 0.73
# Current benign test loss: 0.8473772406578064
# Current adversarial test accuracy: 0.45
# Current adversarial test loss: 1.3981678485870361
#
# Current batch: 30
# Current benign test accuracy: 0.65
# Current benign test loss: 0.930042028427124
# Current adversarial test accuracy: 0.47
# Current adversarial test loss: 1.5349818468093872
#
# Current batch: 40
# Current benign test accuracy: 0.71
# Current benign test loss: 0.8951438665390015
# Current adversarial test accuracy: 0.47
# Current adversarial test loss: 1.5305395126342773
#
# Current batch: 50
# Current benign test accuracy: 0.83
# Current benign test loss: 0.8434216976165771
# Current adversarial test accuracy: 0.45
# Current adversarial test loss: 1.4735808372497559
#
# Current batch: 60
# Current benign test accuracy: 0.69
# Current benign test loss: 0.9544833302497864
# Current adversarial test accuracy: 0.37
# Current adversarial test loss: 1.545653223991394
#
# Current batch: 70
# Current benign test accuracy: 0.74
# Current benign test loss: 0.8500985503196716
# Current adversarial test accuracy: 0.42
# Current adversarial test loss: 1.4812849760055542
#
# Current batch: 80
# Current benign test accuracy: 0.71
# Current benign test loss: 0.894237756729126
# Current adversarial test accuracy: 0.44
# Current adversarial test loss: 1.5784356594085693
#
# Current batch: 90
# Current benign test accuracy: 0.75
# Current benign test loss: 0.8181704878807068
# Current adversarial test accuracy: 0.45
# Current adversarial test loss: 1.4372265338897705
#
# Total benign test accuarcy: 73.65
# Total adversarial test Accuarcy: 44.97
# Total benign test loss: 87.59216940402985
# Total adversarial test loss: 149.60895884037018
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.5078125
# Current adversarial train loss: 1.3755165338516235
#
# Current batch: 10
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.533751130104065
#
# Current batch: 20
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4054346084594727
#
# Current batch: 30
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.4408568143844604
#
# Current batch: 40
# Current adversarial train accuracy: 0.5
# Current adversarial train loss: 1.2695722579956055
#
# Current batch: 50
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.607141137123108
#
# Current batch: 60
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.509361982345581
#
# Current batch: 70
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.335274577140808
#
# Current batch: 80
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.369402289390564
#
# Current batch: 90
# Current adversarial train accuracy: 0.4921875
# Current adversarial train loss: 1.3188250064849854
#
# Current batch: 100
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4691905975341797
#
# Current batch: 110
# Current adversarial train accuracy: 0.4921875
# Current adversarial train loss: 1.3894870281219482
#
# Current batch: 120
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.4131979942321777
#
# Current batch: 130
# Current adversarial train accuracy: 0.4921875
# Current adversarial train loss: 1.3048418760299683
#
# Current batch: 140
# Current adversarial train accuracy: 0.4765625
# Current adversarial train loss: 1.3011929988861084
#
# Current batch: 150
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.4194869995117188
#
# Current batch: 160
# Current adversarial train accuracy: 0.5078125
# Current adversarial train loss: 1.3742536306381226
#
# Current batch: 170
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.356479525566101
#
# Current batch: 180
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 1.5061657428741455
#
# Current batch: 190
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4372437000274658
#
# Current batch: 200
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4006308317184448
#
# Current batch: 210
# Current adversarial train accuracy: 0.4609375
# Current adversarial train loss: 1.3236116170883179
#
# Current batch: 220
# Current adversarial train accuracy: 0.4453125
# Current adversarial train loss: 1.3420358896255493
#
# Current batch: 230
# Current adversarial train accuracy: 0.5
# Current adversarial train loss: 1.3777151107788086
#
# Current batch: 240
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.5407956838607788
#
# Current batch: 250
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.358137845993042
#
# Current batch: 260
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.4575309753417969
#
# Current batch: 270
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4102727174758911
#
# Current batch: 280
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.405871868133545
#
# Current batch: 290
# Current adversarial train accuracy: 0.53125
# Current adversarial train loss: 1.3164602518081665
#
# Current batch: 300
# Current adversarial train accuracy: 0.4921875
# Current adversarial train loss: 1.3830732107162476
#
# Current batch: 310
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.4219048023223877
#
# Current batch: 320
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.315657377243042
#
# Current batch: 330
# Current adversarial train accuracy: 0.5234375
# Current adversarial train loss: 1.2900805473327637
#
# Current batch: 340
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.5579023361206055
#
# Current batch: 350
# Current adversarial train accuracy: 0.4765625
# Current adversarial train loss: 1.3700180053710938
#
# Current batch: 360
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.5375725030899048
#
# Current batch: 370
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.427177906036377
#
# Current batch: 380
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.426551103591919
#
# Current batch: 390
# Current adversarial train accuracy: 0.4875
# Current adversarial train loss: 1.483193039894104
#
# Total adversarial train accuarcy: 45.556
# Total adversarial train loss: 554.518562078476
#
# [ Test epoch: 5 ]
#
# Current batch: 0
# Current benign test accuracy: 0.83
# Current benign test loss: 0.7993330955505371
# Current adversarial test accuracy: 0.51
# Current adversarial test loss: 1.393430233001709
#
# Current batch: 10
# Current benign test accuracy: 0.8
# Current benign test loss: 0.802152693271637
# Current adversarial test accuracy: 0.48
# Current adversarial test loss: 1.4601255655288696
#
# Current batch: 20
# Current benign test accuracy: 0.7
# Current benign test loss: 0.8264879584312439
# Current adversarial test accuracy: 0.44
# Current adversarial test loss: 1.3805278539657593
#
# Current batch: 30
# Current benign test accuracy: 0.72
# Current benign test loss: 0.866557240486145
# Current adversarial test accuracy: 0.44
# Current adversarial test loss: 1.4562125205993652
#
# Current batch: 40
# Current benign test accuracy: 0.73
# Current benign test loss: 0.8838945627212524
# Current adversarial test accuracy: 0.43
# Current adversarial test loss: 1.5209088325500488
#
# Current batch: 50
# Current benign test accuracy: 0.8
# Current benign test loss: 0.8186323642730713
# Current adversarial test accuracy: 0.46
# Current adversarial test loss: 1.4731324911117554
#
# Current batch: 60
# Current benign test accuracy: 0.69
# Current benign test loss: 0.8915852904319763
# Current adversarial test accuracy: 0.41
# Current adversarial test loss: 1.4695974588394165
#
# Current batch: 70
# Current benign test accuracy: 0.72
# Current benign test loss: 0.7831368446350098
# Current adversarial test accuracy: 0.51
# Current adversarial test loss: 1.4000533819198608
#
# Current batch: 80
# Current benign test accuracy: 0.73
# Current benign test loss: 0.8624550104141235
# Current adversarial test accuracy: 0.4
# Current adversarial test loss: 1.5463347434997559
#
# Current batch: 90
# Current benign test accuracy: 0.78
# Current benign test loss: 0.7740474939346313
# Current adversarial test accuracy: 0.44
# Current adversarial test loss: 1.3874449729919434
#
# Total benign test accuarcy: 74.55
# Total adversarial test Accuarcy: 45.78
# Total benign test loss: 82.71395003795624
# Total adversarial test loss: 144.9811841249466
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.4496299028396606
#
# Current batch: 10
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.3747243881225586
#
# Current batch: 20
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.385533094406128
#
# Current batch: 30
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.311214804649353
#
# Current batch: 40
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.427513837814331
#
# Current batch: 50
# Current adversarial train accuracy: 0.5
# Current adversarial train loss: 1.283801555633545
#
# Current batch: 60
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.3412015438079834
#
# Current batch: 70
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.4054666757583618
#
# Current batch: 80
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.4750810861587524
#
# Current batch: 90
# Current adversarial train accuracy: 0.4765625
# Current adversarial train loss: 1.4373250007629395
#
# Current batch: 100
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 1.5666762590408325
#
# Current batch: 110
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.4840619564056396
#
# Current batch: 120
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.4320259094238281
#
# Current batch: 130
# Current adversarial train accuracy: 0.5625
# Current adversarial train loss: 1.2589669227600098
#
# Current batch: 140
# Current adversarial train accuracy: 0.40625
# Current adversarial train loss: 1.3921688795089722
#
# Current batch: 150
# Current adversarial train accuracy: 0.4609375
# Current adversarial train loss: 1.3475180864334106
#
# Current batch: 160
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.5711678266525269
#
# Current batch: 170
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.385377287864685
#
# Current batch: 180
# Current adversarial train accuracy: 0.5234375
# Current adversarial train loss: 1.312952995300293
#
# Current batch: 190
# Current adversarial train accuracy: 0.4609375
# Current adversarial train loss: 1.3632447719573975
#
# Current batch: 200
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.3993762731552124
#
# Current batch: 210
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.3744381666183472
#
# Current batch: 220
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.3486250638961792
#
# Current batch: 230
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.3915517330169678
#
# Current batch: 240
# Current adversarial train accuracy: 0.515625
# Current adversarial train loss: 1.3030556440353394
#
# Current batch: 250
# Current adversarial train accuracy: 0.421875
# Current adversarial train loss: 1.495619535446167
#
# Current batch: 260
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.2786680459976196
#
# Current batch: 270
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.52522611618042
#
# Current batch: 280
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.439108967781067
#
# Current batch: 290
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.413914442062378
#
# Current batch: 300
# Current adversarial train accuracy: 0.4765625
# Current adversarial train loss: 1.4932661056518555
#
# Current batch: 310
# Current adversarial train accuracy: 0.4453125
# Current adversarial train loss: 1.3750457763671875
#
# Current batch: 320
# Current adversarial train accuracy: 0.46875
# Current adversarial train loss: 1.4244613647460938
#
# Current batch: 330
# Current adversarial train accuracy: 0.515625
# Current adversarial train loss: 1.2164674997329712
#
# Current batch: 340
# Current adversarial train accuracy: 0.453125
# Current adversarial train loss: 1.4437611103057861
#
# Current batch: 350
# Current adversarial train accuracy: 0.4375
# Current adversarial train loss: 1.442536473274231
#
# Current batch: 360
# Current adversarial train accuracy: 0.53125
# Current adversarial train loss: 1.2646199464797974
#
# Current batch: 370
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.4156231880187988
#
# Current batch: 380
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.4662916660308838
#
# Current batch: 390
# Current adversarial train accuracy: 0.35
# Current adversarial train loss: 1.501928448677063
#
# Total adversarial train accuarcy: 46.298
# Total adversarial train loss: 545.168683886528
#
# [ Test epoch: 6 ]
#
# Current batch: 0
# Current benign test accuracy: 0.7
# Current benign test loss: 0.8635492920875549
# Current adversarial test accuracy: 0.47
# Current adversarial test loss: 1.466871976852417
#
# Current batch: 10
# Current benign test accuracy: 0.76
# Current benign test loss: 0.7998204231262207
# Current adversarial test accuracy: 0.47
# Current adversarial test loss: 1.4684703350067139
#
# Current batch: 20
# Current benign test accuracy: 0.69
# Current benign test loss: 0.8626500964164734
# Current adversarial test accuracy: 0.47
# Current adversarial test loss: 1.4033879041671753
#
# Current batch: 30
# Current benign test accuracy: 0.72
# Current benign test loss: 0.8515838384628296
# Current adversarial test accuracy: 0.41
# Current adversarial test loss: 1.4677625894546509
#
# Current batch: 40
# Current benign test accuracy: 0.76
# Current benign test loss: 0.8604491353034973
# Current adversarial test accuracy: 0.46
# Current adversarial test loss: 1.4660524129867554
#
# Current batch: 50
# Current benign test accuracy: 0.76
# Current benign test loss: 0.847504734992981
# Current adversarial test accuracy: 0.4
# Current adversarial test loss: 1.5060970783233643
#
# Current batch: 60
# Current benign test accuracy: 0.72
# Current benign test loss: 0.9168593883514404
# Current adversarial test accuracy: 0.44
# Current adversarial test loss: 1.5046954154968262
#
# Current batch: 70
# Current benign test accuracy: 0.72
# Current benign test loss: 0.801280677318573
# Current adversarial test accuracy: 0.48
# Current adversarial test loss: 1.4667798280715942
#
# Current batch: 80
# Current benign test accuracy: 0.76
# Current benign test loss: 0.8374848365783691
# Current adversarial test accuracy: 0.44
# Current adversarial test loss: 1.5187286138534546
#
# Current batch: 90
# Current benign test accuracy: 0.78
# Current benign test loss: 0.7499359250068665
# Current adversarial test accuracy: 0.42
# Current adversarial test loss: 1.3670439720153809
#
# Total benign test accuarcy: 73.58
# Total adversarial test Accuarcy: 44.59
# Total benign test loss: 82.96706062555313
# Total adversarial test loss: 145.39830577373505
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.515625
# Current adversarial train loss: 1.3997268676757812
#
# Current batch: 10
# Current adversarial train accuracy: 0.5078125
# Current adversarial train loss: 1.388200283050537
#
# Current batch: 20
# ...
# Current adversarial train accuracy: 0.7265625
# Current adversarial train loss: 0.6140531301498413
#
# Current batch: 390
# Current adversarial train accuracy: 0.7625
# Current adversarial train loss: 0.5925156474113464
#
# Total adversarial train accuarcy: 73.274
# Total adversarial train loss: 236.9914164841175
#
# [ Test epoch: 72 ]
#
# Current batch: 0
# Current benign test accuracy: 0.81
# Current benign test loss: 0.6032699942588806
# Current adversarial test accuracy: 0.45
# Current adversarial test loss: 1.820314645767212
#
# Current batch: 10
# Current benign test accuracy: 0.87
# Current benign test loss: 0.4543530344963074
# Current adversarial test accuracy: 0.55
# Current adversarial test loss: 1.6068673133850098
#
# Current batch: 20
# Current benign test accuracy: 0.8
# Current benign test loss: 0.5408409237861633
# Current adversarial test accuracy: 0.47
# Current adversarial test loss: 1.4031133651733398
#
# Current batch: 30
# Current benign test accuracy: 0.78
# Current benign test loss: 0.6123049259185791
# Current adversarial test accuracy: 0.51
# Current adversarial test loss: 1.6952558755874634
#
# Current batch: 40
# Current benign test accuracy: 0.8
# Current benign test loss: 0.5904793739318848
# Current adversarial test accuracy: 0.55
# Current adversarial test loss: 1.6734296083450317
#
# Current batch: 50
# Current benign test accuracy: 0.91
# Current benign test loss: 0.5074760913848877
# Current adversarial test accuracy: 0.5
# Current adversarial test loss: 1.6094467639923096
#
# Current batch: 60
# Current benign test accuracy: 0.78
# Current benign test loss: 0.5637590885162354
# Current adversarial test accuracy: 0.42
# Current adversarial test loss: 1.6581110954284668
#
# Current batch: 70
# Current benign test accuracy: 0.81
# Current benign test loss: 0.47429734468460083
# Current adversarial test accuracy: 0.49
# Current adversarial test loss: 1.5219027996063232
#
# Current batch: 80
# Current benign test accuracy: 0.85
# Current benign test loss: 0.48885953426361084
# Current adversarial test accuracy: 0.52
# Current adversarial test loss: 1.663872241973877
#
# Current batch: 90
# Current benign test accuracy: 0.85
# Current benign test loss: 0.40536004304885864
# Current adversarial test accuracy: 0.49
# Current adversarial test loss: 1.4024367332458496
#
# Total benign test accuarcy: 84.35
# Total adversarial test Accuarcy: 51.46
# Total benign test loss: 49.93962121009827
# Total adversarial test loss: 154.19850206375122
# Model Saved!
#
# [ Train epoch: 73 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.75
# Current adversarial train loss: 0.5674633979797363
#
# Current batch: 10
# Current adversarial train accuracy: 0.765625
# Current adversarial train loss: 0.6080979108810425
#
# Current batch: 20
# Current adversarial train accuracy: 0.7265625
# Current adversarial train loss: 0.5924760103225708
#
# Current batch: 30
# Current adversarial train accuracy: 0.765625
# Current adversarial train loss: 0.6199466586112976
#
# Current batch: 40
# Current adversarial train accuracy: 0.8125
# Current adversarial train loss: 0.5049484372138977
#
# Current batch: 50
# Current adversarial train accuracy: 0.7265625
# Current adversarial train loss: 0.565222978591919
#
# Current batch: 60
# Current adversarial train accuracy: 0.75
# Current adversarial train loss: 0.6155998706817627
#
# Current batch: 70
# Current adversarial train accuracy: 0.7578125
# Current adversarial train loss: 0.5241720080375671
#
# Current batch: 80
# Current adversarial train accuracy: 0.734375
# Current adversarial train loss: 0.6452736854553223
#
# Current batch: 90
# Current adversarial train accuracy: 0.7265625
# Current adversarial train loss: 0.6465833187103271
#
# Current batch: 100
# Current adversarial train accuracy: 0.734375
# Current adversarial train loss: 0.6615036725997925
#
# Current batch: 110
# Current adversarial train accuracy: 0.7109375
# Current adversarial train loss: 0.6024684309959412
#
# Current batch: 120
# Current adversarial train accuracy: 0.796875
# Current adversarial train loss: 0.5144714117050171
#
# Current batch: 130
# Current adversarial train accuracy: 0.7421875
# Current adversarial train loss: 0.6417832374572754
#
# Current batch: 140
# Current adversarial train accuracy: 0.71875
# Current adversarial train loss: 0.6634576916694641
#
# Current batch: 150
# Current adversarial train accuracy: 0.765625
# Current adversarial train loss: 0.5477991700172424
#
# Current batch: 160
# Current adversarial train accuracy: 0.7265625
# Current adversarial train loss: 0.6290501356124878
#
# Current batch: 170
# Current adversarial train accuracy: 0.6875
# Current adversarial train loss: 0.6648810505867004
#
# Current batch: 180
# Current adversarial train accuracy: 0.6875
# Current adversarial train loss: 0.615151584148407
#
# Current batch: 190
# Current adversarial train accuracy: 0.75
# Current adversarial train loss: 0.5690314173698425
#
# Current batch: 200
# Current adversarial train accuracy: 0.6796875
# Current adversarial train loss: 0.6666428446769714
#
# Current batch: 210
# Current adversarial train accuracy: 0.703125
# Current adversarial train loss: 0.736893355846405
#
# Current batch: 220
# Current adversarial train accuracy: 0.7265625
# Current adversarial train loss: 0.6061450242996216
#
# Current batch: 230
# Current adversarial train accuracy: 0.7734375
# Current adversarial train loss: 0.5368934273719788
#
# Current batch: 240
# Current adversarial train accuracy: 0.765625
# Current adversarial train loss: 0.5749291777610779
#
# Current batch: 250
# Current adversarial train accuracy: 0.6953125
# Current adversarial train loss: 0.6975263953208923
#
# Current batch: 260
# Current adversarial train accuracy: 0.78125
# Current adversarial train loss: 0.5604863166809082
#
# Current batch: 270
# Current adversarial train accuracy: 0.71875
# Current adversarial train loss: 0.6062850952148438
#
# Current batch: 280
# Current adversarial train accuracy: 0.7265625
# Current adversarial train loss: 0.6102402806282043
#
# Current batch: 290
# Current adversarial train accuracy: 0.6796875
# Current adversarial train loss: 0.6841050386428833
#
# Current batch: 300
# Current adversarial train accuracy: 0.765625
# Current adversarial train loss: 0.6274861693382263
#
# Current batch: 310
# Current adversarial train accuracy: 0.7109375
# Current adversarial train loss: 0.6194319128990173
#
# Current batch: 320
# Current adversarial train accuracy: 0.75
# Current adversarial train loss: 0.5689253807067871
#
# Current batch: 330
# Current adversarial train accuracy: 0.71875
# Current adversarial train loss: 0.6347955465316772
#
# Current batch: 340
# Current adversarial train accuracy: 0.703125
# Current adversarial train loss: 0.6676783561706543
#
# Current batch: 350
# Current adversarial train accuracy: 0.703125
# Current adversarial train loss: 0.6517537832260132
#
# Current batch: 360
# Current adversarial train accuracy: 0.7109375
# Current adversarial train loss: 0.6512134671211243
#
# Current batch: 370
# Current adversarial train accuracy: 0.7890625
# Current adversarial train loss: 0.5704262852668762
#
# Current batch: 380
# Current adversarial train accuracy: 0.71875
# Current adversarial train loss: 0.650824785232544
#
# Current batch: 390
# Current adversarial train accuracy: 0.8
# Current adversarial train loss: 0.5592256784439087
#
# Total adversarial train accuarcy: 73.362
# Total adversarial train loss: 237.35989645123482
#
# [ Test epoch: 73 ]
#
# Current batch: 0
# Current benign test accuracy: 0.8
# Current benign test loss: 0.5848807692527771
# Current adversarial test accuracy: 0.46
# Current adversarial test loss: 1.783238172531128
#
# Current batch: 10
# Current benign test accuracy: 0.88
# Current benign test loss: 0.4504016041755676
# Current adversarial test accuracy: 0.54
# Current adversarial test loss: 1.6416985988616943
#
# Current batch: 20
# Current benign test accuracy: 0.83
# Current benign test loss: 0.530274510383606
# Current adversarial test accuracy: 0.46
# Current adversarial test loss: 1.4241981506347656
#
# Current batch: 30
# Current benign test accuracy: 0.77
# Current benign test loss: 0.6031468510627747
# Current adversarial test accuracy: 0.52
# Current adversarial test loss: 1.666162371635437
#
# Current batch: 40
# Current benign test accuracy: 0.83
# Current benign test loss: 0.5880036950111389
# Current adversarial test accuracy: 0.56
# Current adversarial test loss: 1.6937432289123535
#
# Current batch: 50
# Current benign test accuracy: 0.91
# Current benign test loss: 0.48479560017585754
# Current adversarial test accuracy: 0.49
# Current adversarial test loss: 1.6136492490768433
#
# Current batch: 60
# Current benign test accuracy: 0.77
# Current benign test loss: 0.5586382746696472
# Current adversarial test accuracy: 0.43
# Current adversarial test loss: 1.6330569982528687
#
# Current batch: 70
# Current benign test accuracy: 0.8
# Current benign test loss: 0.4606144428253174
# Current adversarial test accuracy: 0.48
# Current adversarial test loss: 1.5356626510620117
#
# Current batch: 80
# Current benign test accuracy: 0.88
# Current benign test loss: 0.499986469745636
# Current adversarial test accuracy: 0.49
# Current adversarial test loss: 1.6644216775894165
#
# Current batch: 90
# Current benign test accuracy: 0.85
# Current benign test loss: 0.4126439392566681
# Current adversarial test accuracy: 0.49
# Current adversarial test loss: 1.4465835094451904
#
# Total benign test accuarcy: 84.34
# Total adversarial test Accuarcy: 51.58
# Total benign test loss: 49.406429678201675
# Total adversarial test loss: 154.95849740505219
# Model Saved!
#
# [ Train epoch: 74 ]
#
# Current batch: 0
# Current adversarial train accuracy: 0.75
# Current adversarial train loss: 0.5636639595031738
#
# Current batch: 10
# Current adversarial train accuracy: 0.7734375
# Current adversarial train loss: 0.5557313561439514
#
# Current batch: 20
# Current adversarial train accuracy: 0.71875
# Current adversarial train loss: 0.5961834788322449
#
# Current batch: 30
# Current adversarial train accuracy: 0.71875
# Current adversarial train loss: 0.626462459564209
#
# Current batch: 40
# Current adversarial train accuracy: 0.734375
# Current adversarial train loss: 0.543927788734436
#
# Current batch: 50
# Current adversarial train accuracy: 0.6796875
# Current adversarial train loss: 0.672482967376709
#
# Current batch: 60
# Current adversarial train accuracy: 0.734375
# Current adversarial train loss: 0.643695056438446
#
# Current batch: 70
# Current adversarial train accuracy: 0.734375
# Current adversarial train loss: 0.6107794642448425
#
# Current batch: 80
# Current adversarial train accuracy: 0.7421875
# Current adversarial train loss: 0.5735189318656921
#
# Current batch: 90
# Current adversarial train accuracy: 0.734375
# Current adversarial train loss: 0.6859333515167236
#
# Current batch: 100
# Current adversarial train accuracy: 0.7421875
# Current adversarial train loss: 0.5962921380996704
#
# Current batch: 110
# Current adversarial train accuracy: 0.78125
# Current adversarial train loss: 0.5969866514205933
#
# Current batch: 120
# Current adversarial train accuracy: 0.6875
# Current adversarial train loss: 0.592501699924469
#
# Current batch: 130
# Current adversarial train accuracy: 0.71875
# Current adversarial train loss: 0.5601481199264526
#
# Current batch: 140
# Current adversarial train accuracy: 0.6640625
# Current adversarial train loss: 0.6825850605964661
#
# Current batch: 150
# Current adversarial train accuracy: 0.8046875
# Current adversarial train loss: 0.528745174407959
#
# Current batch: 160
# Current adversarial train accuracy: 0.7421875
# Current adversarial train loss: 0.5652161836624146
#
# Current batch: 170
# Current adversarial train accuracy: 0.6640625
# Current adversarial train loss: 0.6353936195373535
#
# Current batch: 180
# Current adversarial train accuracy: 0.8125
# Current adversarial train loss: 0.4991454482078552
#
# Current batch: 190
# Current adversarial train accuracy: 0.7421875
# Current adversarial train loss: 0.6027846932411194
#
# Current batch: 200
# Current adversarial train accuracy: 0.703125
# Current adversarial train loss: 0.680828869342804
#
# Current batch: 210
# Current adversarial train accuracy: 0.734375
# Current adversarial train loss: 0.5435485243797302
#
# Current batch: 220
# Current adversarial train accuracy: 0.6796875
# Current adversarial train loss: 0.5878341197967529
#
# Current batch: 230
# Current adversarial train accuracy: 0.7578125
# Current adversarial train loss: 0.5430015325546265
#
# Current batch: 240
# Current adversarial train accuracy: 0.765625
# Current adversarial train loss: 0.6005606651306152
#
# Current batch: 250
# Current adversarial train accuracy: 0.75
# Current adversarial train loss: 0.5951046943664551
#
# Current batch: 260
# Current adversarial train accuracy: 0.6953125
# Current adversarial train loss: 0.6461065411567688
#
# Current batch: 270
# Current adversarial train accuracy: 0.6875
# Current adversarial train loss: 0.626824676990509
#
# Current batch: 280
# Current adversarial train accuracy: 0.703125
# Current adversarial train loss: 0.6249343752861023
#
# Current batch: 290
# Current adversarial train accuracy: 0.71875
# Current adversarial train loss: 0.5474820137023926
#
# Current batch: 300
# Current adversarial train accuracy: 0.7734375
# Current adversarial train loss: 0.5501931309700012
#
# Current batch: 310
# Current adversarial train accuracy: 0.765625
# Current adversarial train loss: 0.4967726767063141
#
# Current batch: 320
# Current adversarial train accuracy: 0.671875
# Current adversarial train loss: 0.7193530201911926
#
# Current batch: 330
# Current adversarial train accuracy: 0.6953125
# Current adversarial train loss: 0.6814402341842651
#
# Current batch: 340
# Current adversarial train accuracy: 0.75
# Current adversarial train loss: 0.5820603966712952
#
# Current batch: 350
# Current adversarial train accuracy: 0.7890625
# Current adversarial train loss: 0.49854540824890137
#
# Current batch: 360
# Current adversarial train accuracy: 0.65625
# Current adversarial train loss: 0.6633833050727844
#
# Current batch: 370
# Current adversarial train accuracy: 0.734375
# Current adversarial train loss: 0.6093814969062805
#
# Current batch: 380
# Current adversarial train accuracy: 0.6875
# Current adversarial train loss: 0.6966928839683533
#
# Current batch: 390
# Current adversarial train accuracy: 0.75
# Current adversarial train loss: 0.6685219407081604
#
# Total adversarial train accuarcy: 73.284
# Total adversarial train loss: 236.40481969714165
#
# [ Test epoch: 74 ]
#
# Current batch: 0
# Current benign test accuracy: 0.82
# Current benign test loss: 0.6038851737976074
# Current adversarial test accuracy: 0.47
# Current adversarial test loss: 1.8556671142578125
#
# Current batch: 10
# Current benign test accuracy: 0.86
# Current benign test loss: 0.44173842668533325
# Current adversarial test accuracy: 0.54
# Current adversarial test loss: 1.6603953838348389
#
# Current batch: 20
# Current benign test accuracy: 0.82
# Current benign test loss: 0.5330755114555359
# Current adversarial test accuracy: 0.49
# Current adversarial test loss: 1.4250527620315552
#
# Current batch: 30
# Current benign test accuracy: 0.78
# Current benign test loss: 0.6170098781585693
# Current adversarial test accuracy: 0.5
# Current adversarial test loss: 1.7305783033370972
#
# Current batch: 40
# Current benign test accuracy: 0.82
# Current benign test loss: 0.588874340057373
# Current adversarial test accuracy: 0.55
# Current adversarial test loss: 1.7057453393936157
#
# Current batch: 50
# Current benign test accuracy: 0.9
# Current benign test loss: 0.49687013030052185
# Current adversarial test accuracy: 0.5
# Current adversarial test loss: 1.702711582183838
#
# Current batch: 60
# Current benign test accuracy: 0.79
# Current benign test loss: 0.5584222674369812
# Current adversarial test accuracy: 0.39
# Current adversarial test loss: 1.6642968654632568
#
# Current batch: 70
# Current benign test accuracy: 0.8
# Current benign test loss: 0.46623554825782776
# Current adversarial test accuracy: 0.48
# Current adversarial test loss: 1.6371809244155884
#
# Current batch: 80
# Current benign test accuracy: 0.83
# Current benign test loss: 0.5224153995513916
# Current adversarial test accuracy: 0.5
# Current adversarial test loss: 1.7474403381347656
#
# Current batch: 90
# Current benign test accuracy: 0.85
# Current benign test loss: 0.43343889713287354
# Current adversarial test accuracy: 0.48
# Current adversarial test loss: 1.5171486139297485
#
# Total benign test accuarcy: 84.61
# Total adversarial test Accuarcy: 50.81
# Total benign test loss: 49.72083628177643
# Total adversarial test loss: 159.64447736740112
# Model Saved!

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion * planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])
def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
net = ResNet18()
net = net.to(device)
cudnn.benchmark = True
checkpoint = torch.load('./checkpoint/' + file_name)
net.load_state_dict(checkpoint['net'])
# Out:
# <All keys matched successfully>

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
])
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
test_loader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
l = [x for (x, y) in test_loader]
x_test = torch.cat(l, 0)
l = [y for (x, y) in test_loader]
y_test = torch.cat(l, 0)
# Out:
# Files already downloaded and verified

# %%
def eval_test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, size_average=False).item()
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    print('Test: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    test_accuracy = correct / len(test_loader.dataset)
    return test_loss, test_accuracy
eval_test(net, device, test_loader)
# Out:
# C:\Users\zahra\anaconda3\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test: Average loss: 0.4972, Accuracy: 8461/10000 (85%)
# (0.49720836353302, 0.8461)

# %%
# !pip install git+https://github.com/fra31/auto-attack
# Out:
# Collecting git+https://github.com/fra31/auto-attack
#   Cloning https://github.com/fra31/auto-attack to c:\users\zahra\appdata\local\temp\pip-req-build-h_woxxtj
#   Resolved https://github.com/fra31/auto-attack to commit a39220048b3c9f2cca9a4d3a54604793c68eca7e
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Running command git clone --filter=blob:none --quiet https://github.com/fra31/auto-attack 'C:\Users\zahra\AppData\Local\Temp\pip-req-build-h_woxxtj'

# %%
from autoattack import AutoAttack
adversary = AutoAttack(net, norm='Linf', eps=0.031, version='standard')
# Out:
# setting parameters for standard version

# %%
adv_complete = adversary.run_standard_evaluation(x_test, y_test,bs=100)
# Out:
# using standard version including apgd-ce, apgd-t, fab-t, square.
# initial accuracy: 84.61%
# apgd-ce - 1/85 - 45 out of 100 successfully perturbed
# apgd-ce - 2/85 - 48 out of 100 successfully perturbed
# apgd-ce - 3/85 - 43 out of 100 successfully perturbed
# apgd-ce - 4/85 - 48 out of 100 successfully perturbed
# apgd-ce - 5/85 - 35 out of 100 successfully perturbed
# apgd-ce - 6/85 - 50 out of 100 successfully perturbed
# apgd-ce - 7/85 - 47 out of 100 successfully perturbed
# apgd-ce - 8/85 - 42 out of 100 successfully perturbed
# apgd-ce - 9/85 - 44 out of 100 successfully perturbed
# apgd-ce - 10/85 - 42 out of 100 successfully perturbed
# apgd-ce - 11/85 - 39 out of 100 successfully perturbed
# apgd-ce - 12/85 - 40 out of 100 successfully perturbed
# apgd-ce - 13/85 - 43 out of 100 successfully perturbed
# apgd-ce - 14/85 - 53 out of 100 successfully perturbed
# apgd-ce - 15/85 - 42 out of 100 successfully perturbed
# apgd-ce - 16/85 - 47 out of 100 successfully perturbed
# apgd-ce - 17/85 - 46 out of 100 successfully perturbed
# apgd-ce - 18/85 - 42 out of 100 successfully perturbed
# apgd-ce - 19/85 - 40 out of 100 successfully perturbed
# apgd-ce - 20/85 - 47 out of 100 successfully perturbed
# apgd-ce - 21/85 - 45 out of 100 successfully perturbed
# apgd-ce - 22/85 - 52 out of 100 successfully perturbed
# apgd-ce - 23/85 - 45 out of 100 successfully perturbed
# apgd-ce - 24/85 - 40 out of 100 successfully perturbed
# apgd-ce - 25/85 - 44 out of 100 successfully perturbed
# apgd-ce - 26/85 - 43 out of 100 successfully perturbed
# apgd-ce - 27/85 - 35 out of 100 successfully perturbed
# apgd-ce - 28/85 - 41 out of 100 successfully perturbed
# apgd-ce - 29/85 - 43 out of 100 successfully perturbed
# apgd-ce - 30/85 - 38 out of 100 successfully perturbed
# apgd-ce - 31/85 - 44 out of 100 successfully perturbed
# apgd-ce - 32/85 - 44 out of 100 successfully perturbed
# apgd-ce - 33/85 - 50 out of 100 successfully perturbed
# apgd-ce - 34/85 - 39 out of 100 successfully perturbed
# apgd-ce - 35/85 - 41 out of 100 successfully perturbed
# apgd-ce - 36/85 - 46 out of 100 successfully perturbed
# apgd-ce - 37/85 - 43 out of 100 successfully perturbed
# apgd-ce - 38/85 - 39 out of 100 successfully perturbed
# apgd-ce - 39/85 - 46 out of 100 successfully perturbed
# apgd-ce - 40/85 - 44 out of 100 successfully perturbed
# apgd-ce - 41/85 - 38 out of 100 successfully perturbed
# apgd-ce - 42/85 - 48 out of 100 successfully perturbed
# apgd-ce - 43/85 - 49 out of 100 successfully perturbed
# apgd-ce - 44/85 - 47 out of 100 successfully perturbed
# apgd-ce - 45/85 - 47 out of 100 successfully perturbed
# apgd-ce - 46/85 - 36 out of 100 successfully perturbed
# apgd-ce - 47/85 - 50 out of 100 successfully perturbed
# apgd-ce - 48/85 - 46 out of 100 successfully perturbed
# apgd-ce - 49/85 - 44 out of 100 successfully perturbed
# apgd-ce - 50/85 - 49 out of 100 successfully perturbed
# apgd-ce - 51/85 - 54 out of 100 successfully perturbed
# apgd-ce - 52/85 - 43 out of 100 successfully perturbed
# apgd-ce - 53/85 - 44 out of 100 successfully perturbed
# apgd-ce - 54/85 - 42 out of 100 successfully perturbed
# apgd-ce - 55/85 - 56 out of 100 successfully perturbed
# apgd-ce - 56/85 - 45 out of 100 successfully perturbed
# apgd-ce - 57/85 - 41 out of 100 successfully perturbed
# apgd-ce - 58/85 - 51 out of 100 successfully perturbed
# apgd-ce - 59/85 - 50 out of 100 successfully perturbed
# apgd-ce - 60/85 - 41 out of 100 successfully perturbed
# apgd-ce - 61/85 - 48 out of 100 successfully perturbed
# apgd-ce - 62/85 - 53 out of 100 successfully perturbed
# apgd-ce - 63/85 - 45 out of 100 successfully perturbed
# apgd-ce - 64/85 - 39 out of 100 successfully perturbed
# apgd-ce - 65/85 - 48 out of 100 successfully perturbed
# apgd-ce - 66/85 - 37 out of 100 successfully perturbed
# apgd-ce - 67/85 - 44 out of 100 successfully perturbed
# apgd-ce - 68/85 - 42 out of 100 successfully perturbed
# apgd-ce - 69/85 - 45 out of 100 successfully perturbed
# apgd-ce - 70/85 - 43 out of 100 successfully perturbed
# apgd-ce - 71/85 - 55 out of 100 successfully perturbed
# apgd-ce - 72/85 - 42 out of 100 successfully perturbed
# apgd-ce - 73/85 - 46 out of 100 successfully perturbed
# apgd-ce - 74/85 - 58 out of 100 successfully perturbed
# apgd-ce - 75/85 - 41 out of 100 successfully perturbed
# apgd-ce - 76/85 - 41 out of 100 successfully perturbed
# apgd-ce - 77/85 - 49 out of 100 successfully perturbed
# apgd-ce - 78/85 - 41 out of 100 successfully perturbed
# apgd-ce - 79/85 - 44 out of 100 successfully perturbed
# apgd-ce - 80/85 - 52 out of 100 successfully perturbed
# apgd-ce - 81/85 - 46 out of 100 successfully perturbed
# apgd-ce - 82/85 - 36 out of 100 successfully perturbed
# apgd-ce - 83/85 - 50 out of 100 successfully perturbed
# apgd-ce - 84/85 - 38 out of 100 successfully perturbed
# apgd-ce - 85/85 - 23 out of 61 successfully perturbed
# robust accuracy after APGD-CE: 46.89% (total time 268.3 s)
# apgd-t - 1/47 - 5 out of 100 successfully perturbed
# apgd-t - 2/47 - 2 out of 100 successfully perturbed
# apgd-t - 3/47 - 8 out of 100 successfully perturbed
# apgd-t - 4/47 - 5 out of 100 successfully perturbed
# apgd-t - 5/47 - 3 out of 100 successfully perturbed
# apgd-t - 6/47 - 8 out of 100 successfully perturbed
# apgd-t - 7/47 - 2 out of 100 successfully perturbed
# apgd-t - 8/47 - 8 out of 100 successfully perturbed
# apgd-t - 9/47 - 1 out of 100 successfully perturbed
# apgd-t - 10/47 - 1 out of 100 successfully perturbed
# apgd-t - 11/47 - 5 out of 100 successfully perturbed
# apgd-t - 12/47 - 4 out of 100 successfully perturbed
# apgd-t - 13/47 - 3 out of 100 successfully perturbed
# apgd-t - 14/47 - 9 out of 100 successfully perturbed
# apgd-t - 15/47 - 3 out of 100 successfully perturbed
# apgd-t - 16/47 - 6 out of 100 successfully perturbed
# apgd-t - 17/47 - 5 out of 100 successfully perturbed
# apgd-t - 18/47 - 4 out of 100 successfully perturbed
# apgd-t - 19/47 - 3 out of 100 successfully perturbed
# apgd-t - 20/47 - 4 out of 100 successfully perturbed
# apgd-t - 21/47 - 3 out of 100 successfully perturbed
# apgd-t - 22/47 - 9 out of 100 successfully perturbed
# apgd-t - 23/47 - 0 out of 100 successfully perturbed
# apgd-t - 24/47 - 4 out of 100 successfully perturbed
# apgd-t - 25/47 - 2 out of 100 successfully perturbed
# apgd-t - 26/47 - 6 out of 100 successfully perturbed
# apgd-t - 27/47 - 7 out of 100 successfully perturbed
# apgd-t - 28/47 - 3 out of 100 successfully perturbed
# apgd-t - 29/47 - 4 out of 100 successfully perturbed
# apgd-t - 30/47 - 3 out of 100 successfully perturbed
# apgd-t - 31/47 - 8 out of 100 successfully perturbed
# apgd-t - 32/47 - 4 out of 100 successfully perturbed
# apgd-t - 33/47 - 7 out of 100 successfully perturbed
# apgd-t - 34/47 - 3 out of 100 successfully perturbed
# apgd-t - 35/47 - 9 out of 100 successfully perturbed
# apgd-t - 36/47 - 4 out of 100 successfully perturbed
# apgd-t - 37/47 - 9 out of 100 successfully perturbed
# apgd-t - 38/47 - 4 out of 100 successfully perturbed
# apgd-t - 39/47 - 4 out of 100 successfully perturbed
# apgd-t - 40/47 - 6 out of 100 successfully perturbed
# apgd-t - 41/47 - 5 out of 100 successfully perturbed
# apgd-t - 42/47 - 5 out of 100 successfully perturbed
# apgd-t - 43/47 - 7 out of 100 successfully perturbed
# apgd-t - 44/47 - 6 out of 100 successfully perturbed
# apgd-t - 45/47 - 3 out of 100 successfully perturbed
# apgd-t - 46/47 - 1 out of 100 successfully perturbed
# apgd-t - 47/47 - 7 out of 89 successfully perturbed
# robust accuracy after APGD-T: 44.67% (total time 1472.5 s)
# fab-t - 1/45 - 0 out of 100 successfully perturbed
# fab-t - 2/45 - 0 out of 100 successfully perturbed
# fab-t - 3/45 - 0 out of 100 successfully perturbed
# fab-t - 4/45 - 0 out of 100 successfully perturbed
# fab-t - 5/45 - 0 out of 100 successfully perturbed
# fab-t - 6/45 - 0 out of 100 successfully perturbed
# fab-t - 7/45 - 0 out of 100 successfully perturbed
# fab-t - 8/45 - 0 out of 100 successfully perturbed
# fab-t - 9/45 - 0 out of 100 successfully perturbed
# fab-t - 10/45 - 0 out of 100 successfully perturbed
# fab-t - 11/45 - 0 out of 100 successfully perturbed
# fab-t - 12/45 - 0 out of 100 successfully perturbed
# fab-t - 13/45 - 0 out of 100 successfully perturbed
# fab-t - 14/45 - 0 out of 100 successfully perturbed
# fab-t - 15/45 - 0 out of 100 successfully perturbed
# fab-t - 16/45 - 0 out of 100 successfully perturbed
# fab-t - 17/45 - 0 out of 100 successfully perturbed
# fab-t - 18/45 - 0 out of 100 successfully perturbed
# fab-t - 19/45 - 0 out of 100 successfully perturbed
# fab-t - 20/45 - 0 out of 100 successfully perturbed
# fab-t - 21/45 - 0 out of 100 successfully perturbed
# fab-t - 22/45 - 0 out of 100 successfully perturbed
# fab-t - 23/45 - 0 out of 100 successfully perturbed
# fab-t - 24/45 - 0 out of 100 successfully perturbed
# fab-t - 25/45 - 0 out of 100 successfully perturbed
# fab-t - 26/45 - 0 out of 100 successfully perturbed
# fab-t - 27/45 - 0 out of 100 successfully perturbed
# fab-t - 28/45 - 0 out of 100 successfully perturbed
# fab-t - 29/45 - 0 out of 100 successfully perturbed
# fab-t - 30/45 - 0 out of 100 successfully perturbed
# fab-t - 31/45 - 0 out of 100 successfully perturbed
# fab-t - 32/45 - 0 out of 100 successfully perturbed
# fab-t - 33/45 - 0 out of 100 successfully perturbed
# fab-t - 34/45 - 0 out of 100 successfully perturbed
# fab-t - 35/45 - 0 out of 100 successfully perturbed
# fab-t - 36/45 - 0 out of 100 successfully perturbed
# fab-t - 37/45 - 0 out of 100 successfully perturbed
# fab-t - 38/45 - 0 out of 100 successfully perturbed
# fab-t - 39/45 - 0 out of 100 successfully perturbed
# fab-t - 40/45 - 0 out of 100 successfully perturbed
# fab-t - 41/45 - 0 out of 100 successfully perturbed
# fab-t - 42/45 - 0 out of 100 successfully perturbed
# fab-t - 43/45 - 0 out of 100 successfully perturbed
# fab-t - 44/45 - 0 out of 100 successfully perturbed
# fab-t - 45/45 - 0 out of 67 successfully perturbed
# robust accuracy after FAB-T: 44.67% (total time 3967.5 s)
# square - 1/45 - 0 out of 100 successfully perturbed
# square - 2/45 - 0 out of 100 successfully perturbed
# square - 3/45 - 0 out of 100 successfully perturbed
# square - 4/45 - 0 out of 100 successfully perturbed
# square - 5/45 - 0 out of 100 successfully perturbed
# square - 6/45 - 0 out of 100 successfully perturbed
# square - 7/45 - 0 out of 100 successfully perturbed
# square - 8/45 - 0 out of 100 successfully perturbed
# square - 9/45 - 0 out of 100 successfully perturbed
# square - 10/45 - 0 out of 100 successfully perturbed
# square - 11/45 - 0 out of 100 successfully perturbed
# square - 12/45 - 0 out of 100 successfully perturbed
# square - 13/45 - 0 out of 100 successfully perturbed
# square - 14/45 - 0 out of 100 successfully perturbed
# square - 15/45 - 0 out of 100 successfully perturbed
# square - 16/45 - 0 out of 100 successfully perturbed
# square - 17/45 - 0 out of 100 successfully perturbed
# square - 18/45 - 0 out of 100 successfully perturbed
# square - 19/45 - 0 out of 100 successfully perturbed
# square - 20/45 - 0 out of 100 successfully perturbed
# square - 21/45 - 0 out of 100 successfully perturbed
# square - 22/45 - 0 out of 100 successfully perturbed
# square - 23/45 - 0 out of 100 successfully perturbed
# square - 24/45 - 0 out of 100 successfully perturbed
# square - 25/45 - 0 out of 100 successfully perturbed
# square - 26/45 - 0 out of 100 successfully perturbed
# square - 27/45 - 0 out of 100 successfully perturbed
# square - 28/45 - 0 out of 100 successfully perturbed
# square - 29/45 - 0 out of 100 successfully perturbed
# square - 30/45 - 0 out of 100 successfully perturbed
# square - 31/45 - 0 out of 100 successfully perturbed
# square - 32/45 - 0 out of 100 successfully perturbed
# square - 33/45 - 0 out of 100 successfully perturbed
# square - 34/45 - 0 out of 100 successfully perturbed
# square - 35/45 - 0 out of 100 successfully perturbed
# square - 36/45 - 0 out of 100 successfully perturbed
# square - 37/45 - 0 out of 100 successfully perturbed
# square - 38/45 - 0 out of 100 successfully perturbed
# square - 39/45 - 0 out of 100 successfully perturbed
# square - 40/45 - 0 out of 100 successfully perturbed
# square - 41/45 - 0 out of 100 successfully perturbed
# square - 42/45 - 0 out of 100 successfully perturbed
# square - 43/45 - 0 out of 100 successfully perturbed
# square - 44/45 - 0 out of 100 successfully perturbed
# square - 45/45 - 0 out of 67 successfully perturbed
# robust accuracy after SQUARE: 44.67% (total time 7096.7 s)
# max Linf perturbation: 0.03100, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 44.67%

# %%
adv_loader_Linf = torch.utils.data.DataLoader(adv_complete, batch_size=100, shuffle=False, num_workers=2)
num_total_images = 0
num_successful_attacks = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
    for adv_images in adv_loader_Linf:
        adv_images = adv_images.to(device)
        outputs_adv = net(adv_images)
        _, predicted_adv = torch.max(outputs_adv.data, 1)

        # Count the number of adversarial examples that were successfully attacked
        for i in range(len(images)):
            if predicted[i] != predicted_adv[i]:
                num_successful_attacks += 1
        
        # Increment the total number of images
        num_total_images += len(images)

# Calculate the adversarial attack rate
attack_rate = (num_successful_attacks / num_total_images) * 100
print(f"Adversarial attack rate: {attack_rate:.2f}%")
# Out:
# Adversarial attack rate: 89.32%

# %%
from autoattack import AutoAttack
adversary_L2 = AutoAttack(net, norm='L2', eps=0.031, version='standard')
adv_complete_L2 = adversary_L2.run_standard_evaluation(x_test, y_test,bs=200)

# %%
adv_loader_L2 = torch.utils.data.DataLoader(adv_complete_L2, batch_size=100, shuffle=False, num_workers=2)
num_total_images = 0
num_successful_attacks = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
    for adv_images in adv_loader_L2:
        adv_images = adv_images.to(device)
        outputs_adv = net(adv_images)
        _, predicted_adv = torch.max(outputs_adv.data, 1)

        # Count the number of adversarial examples that were successfully attacked
        for i in range(len(images)):
            if predicted[i] != predicted_adv[i]:
                num_successful_attacks += 1
        
        # Increment the total number of images
        num_total_images += len(images)

# Calculate the adversarial attack rate
attack_rate = (num_successful_attacks / num_total_images) * 100
print(f"Adversarial attack rate: {attack_rate:.2f}%")
