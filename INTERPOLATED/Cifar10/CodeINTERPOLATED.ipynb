# %%
from __future__ import print_function
import os
import argparse
import sys
sys.argv
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from torchvision import datasets, transforms
import random
import numpy as np
SEED=1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.benchmark = False
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion * planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])
def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
from __future__ import print_function
import os
import argparse
import sys
sys.argv
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from torchvision import datasets, transforms
import random
import numpy as np
SEED=1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.benchmark = False
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion * planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])
def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
if not os.path.exists('model-resnet-epoch76.pt'):
    os.makedirs('model-resnet-epoch76.pt')
use_cuda = not False and torch.cuda.is_available()
torch.manual_seed(1)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
net=ResNet18()
net.load_state_dict(torch.load('model-resnet-epoch76.pt'))
net.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=100, bias=True)
# )

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

#interpolated_adversarial_training
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import os
import numpy as np

#from models import *

learning_rate = 0.1
epsilon = 0.0314
k = 7
alpha = 0.00784
file_name = 'interpolated_adversarial_training'
mixup_alpha = 1.0

device = 'cuda' if torch.cuda.is_available() else 'cpu'

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)

def mixup_data(x, y):
    lam = np.random.beta(mixup_alpha, mixup_alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

class LinfPGDAttack(object):
    def __init__(self, model):
        self.model = model

    def perturb(self, x_natural, y):
        x = x_natural.detach()
        x = x + torch.zeros_like(x).uniform_(-8/225, 8/225)
        for i in range(k):
            x.requires_grad_()
            with torch.enable_grad():
                logits = self.model(x)
                loss = F.cross_entropy(logits, y)
            grad = torch.autograd.grad(loss, [x])[0]
            x = x.detach() + alpha * torch.sign(grad.detach())
            x = torch.min(torch.max(x, x_natural - 8/225), x_natural + 8/225)
            x = torch.clamp(x, 0, 1)
        return x

def attack(x, y, model, adversary):
    model_copied = copy.deepcopy(model)
    model_copied.eval()
    adversary.model = model_copied
    adv = adversary.perturb(x, y)
    return adv

#net = ResNet18()
#net = net.to(device)
#net = torch.nn.DataParallel(net)
#cudnn.benchmark = True

adversary = LinfPGDAttack(net)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    benign_loss = 0
    adv_loss = 0
    benign_correct = 0
    adv_correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)
        optimizer.zero_grad()

        benign_inputs, benign_targets_a, benign_targets_b, benign_lam = mixup_data(inputs, targets)
        benign_outputs = net(benign_inputs)
        loss1 = mixup_criterion(criterion, benign_outputs, benign_targets_a, benign_targets_b, benign_lam)
        benign_loss += loss1.item()

        _, predicted = benign_outputs.max(1)
        benign_correct += (benign_lam * predicted.eq(benign_targets_a).sum().float() + (1 - benign_lam) * predicted.eq(benign_targets_b).sum().float())
        if batch_idx % 10 == 0:
                print('\nCurrent batch:', str(batch_idx))
                print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
                print('Current benign train loss:', loss1.item())

        adv = adversary.perturb(inputs, targets)
        adv_inputs, adv_targets_a, adv_targets_b, adv_lam = mixup_data(adv, targets)
        adv_outputs = net(adv_inputs)
        loss2 = mixup_criterion(criterion, adv_outputs, adv_targets_a, adv_targets_b, adv_lam)
        adv_loss += loss2.item()

        _, predicted = adv_outputs.max(1)
        adv_correct += (adv_lam * predicted.eq(adv_targets_a).sum().float() + (1 - adv_lam) * predicted.eq(adv_targets_b).sum().float())
        if batch_idx % 10 == 0:
                print('Current adversarial train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
                print('Current adversarial train loss:', loss2.item())

        loss = (loss1 + loss2) / 2
        loss.backward()
        optimizer.step()

    print('\nTotal benign train accuarcy:', 100. * benign_correct / total)
    print('Total adversarial train accuarcy:', 100. * adv_correct / total)
    print('Total benign train loss:', benign_loss)
    print('Total adversarial train loss:', adv_loss)

def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    benign_loss = 0
    adv_loss = 0
    benign_correct = 0
    adv_correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            total += targets.size(0)

            outputs = net(inputs)
            loss = criterion(outputs, targets)
            benign_loss += loss.item()

            _, predicted = outputs.max(1)
            benign_correct += predicted.eq(targets).sum().item()

            if batch_idx % 10 == 0:
                print('\nCurrent batch:', str(batch_idx))
                print('Current benign test accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
                print('Current benign test loss:', loss.item())

            adv = adversary.perturb(inputs, targets)
            adv_outputs = net(adv)
            loss = criterion(adv_outputs, targets)
            adv_loss += loss.item()

            _, predicted = adv_outputs.max(1)
            adv_correct += predicted.eq(targets).sum().item()

            if batch_idx % 10 == 0:
                print('Current adversarial test accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
                print('Current adversarial test loss:', loss.item())

    print('\nTotal benign test accuarcy:', 100. * benign_correct / total)
    print('Total adversarial test Accuarcy:', 100. * adv_correct / total)
    print('Total benign test loss:', benign_loss)
    print('Total adversarial test loss:', adv_loss)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 32:
        lr /= 10
    if epoch >= 50:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

for epoch in range(0, 75):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current benign train accuracy: 0.109375
# Current benign train loss: 2.46075439453125
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 7.986547946929932
#
# Current batch: 10
# Current benign train accuracy: 0.0859375
# Current benign train loss: 1.3235186338424683
# Current adversarial train accuracy: 0.0234375
# Current adversarial train loss: 3.0714616775512695
#
# Current batch: 20
# Current benign train accuracy: 0.28125
# Current benign train loss: 2.195127487182617
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 2.4193902015686035
#
# Current batch: 30
# Current benign train accuracy: 0.140625
# Current benign train loss: 1.8537505865097046
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 2.2363810539245605
#
# Current batch: 40
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.690442442893982
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 2.1518235206604004
#
# Current batch: 50
# Current benign train accuracy: 0.453125
# Current benign train loss: 1.741913080215454
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 2.222168207168579
#
# Current batch: 60
# Current benign train accuracy: 0.15625
# Current benign train loss: 1.615445613861084
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 2.14029860496521
#
# Current batch: 70
# Current benign train accuracy: 0.1796875
# Current benign train loss: 1.9047307968139648
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.11867094039917
#
# Current batch: 80
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.4491184949874878
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 2.27376651763916
#
# Current batch: 90
# Current benign train accuracy: 0.703125
# Current benign train loss: 1.2909657955169678
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 2.1432647705078125
#
# Current batch: 100
# Current benign train accuracy: 0.1484375
# Current benign train loss: 1.847541093826294
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 2.2175209522247314
#
# Current batch: 110
# Current benign train accuracy: 0.140625
# Current benign train loss: 1.1651742458343506
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 2.1394357681274414
#
# Current batch: 120
# Current benign train accuracy: 0.703125
# Current benign train loss: 1.170819640159607
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 2.0899064540863037
#
# Current batch: 130
# Current benign train accuracy: 0.09375
# Current benign train loss: 1.2363357543945312
# Current adversarial train accuracy: 0.171875
# Current adversarial train loss: 2.122992992401123
#
# Current batch: 140
# Current benign train accuracy: 0.1796875
# Current benign train loss: 1.433248519897461
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.9924181699752808
#
# Current batch: 150
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.6770918369293213
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 2.017718553543091
#
# Current batch: 160
# Current benign train accuracy: 0.1484375
# Current benign train loss: 1.8215054273605347
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.1208724975585938
#
# Current batch: 170
# Current benign train accuracy: 0.7890625
# Current benign train loss: 1.1913880109786987
# Current adversarial train accuracy: 0.15625
# Current adversarial train loss: 2.141375780105591
#
# Current batch: 180
# Current benign train accuracy: 0.3203125
# Current benign train loss: 1.7146835327148438
# Current adversarial train accuracy: 0.359375
# Current adversarial train loss: 1.9702067375183105
#
# Current batch: 190
# Current benign train accuracy: 0.7421875
# Current benign train loss: 1.1010236740112305
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 2.0602023601531982
#
# Current batch: 200
# Current benign train accuracy: 0.1875
# Current benign train loss: 1.8955137729644775
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.1226696968078613
#
# Current batch: 210
# Current benign train accuracy: 0.6953125
# Current benign train loss: 1.6496412754058838
# Current adversarial train accuracy: 0.046875
# Current adversarial train loss: 2.021477460861206
#
# Current batch: 220
# Current benign train accuracy: 0.1015625
# Current benign train loss: 1.2610437870025635
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 1.9703611135482788
#
# Current batch: 230
# Current benign train accuracy: 0.3515625
# Current benign train loss: 1.822405219078064
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 2.125904083251953
#
# Current batch: 240
# Current benign train accuracy: 0.671875
# Current benign train loss: 1.6598584651947021
# Current adversarial train accuracy: 0.109375
# Current adversarial train loss: 1.908359408378601
#
# Current batch: 250
# Current benign train accuracy: 0.2109375
# Current benign train loss: 1.722839117050171
# Current adversarial train accuracy: 0.0703125
# Current adversarial train loss: 2.000861644744873
#
# Current batch: 260
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.7117116451263428
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.065490245819092
#
# Current batch: 270
# Current benign train accuracy: 0.1015625
# Current benign train loss: 1.488443374633789
# Current adversarial train accuracy: 0.109375
# Current adversarial train loss: 1.9511605501174927
#
# Current batch: 280
# Current benign train accuracy: 0.7109375
# Current benign train loss: 1.6582601070404053
# Current adversarial train accuracy: 0.09375
# Current adversarial train loss: 1.9377567768096924
#
# Current batch: 290
# Current benign train accuracy: 0.3203125
# Current benign train loss: 1.8387255668640137
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.1296451091766357
#
# Current batch: 300
# Current benign train accuracy: 0.1875
# Current benign train loss: 1.8639490604400635
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.142652988433838
#
# Current batch: 310
# Current benign train accuracy: 0.078125
# Current benign train loss: 1.2001829147338867
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 2.0486271381378174
#
# Current batch: 320
# Current benign train accuracy: 0.078125
# Current benign train loss: 1.2213307619094849
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.1364119052886963
#
# Current batch: 330
# Current benign train accuracy: 0.171875
# Current benign train loss: 1.2756898403167725
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.024165153503418
#
# Current batch: 340
# Current benign train accuracy: 0.3828125
# Current benign train loss: 1.7622623443603516
# Current adversarial train accuracy: 0.0859375
# Current adversarial train loss: 1.933955192565918
#
# Current batch: 350
# Current benign train accuracy: 0.7578125
# Current benign train loss: 1.5658063888549805
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 1.9114375114440918
#
# Current batch: 360
# Current benign train accuracy: 0.09375
# Current benign train loss: 0.9712377190589905
# Current adversarial train accuracy: 0.0703125
# Current adversarial train loss: 1.7487705945968628
#
# Current batch: 370
# Current benign train accuracy: 0.0859375
# Current benign train loss: 1.3514249324798584
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 1.9923545122146606
#
# Current batch: 380
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.6491420269012451
# Current adversarial train accuracy: 0.109375
# Current adversarial train loss: 1.8172805309295654
#
# Current batch: 390
# Current benign train accuracy: 0.8625
# Current benign train loss: 1.2123732566833496
# Current adversarial train accuracy: 0.35
# Current adversarial train loss: 2.0364155769348145
#
# Total benign train accuarcy: tensor(54.6114, device='cuda:0')
# Total adversarial train accuarcy: tensor(23.3982, device='cuda:0')
# Total benign train loss: 601.0033426880836
# Total adversarial train loss: 870.5135188102722
#
# [ Test epoch: 0 ]
#
# Current batch: 0
# Current benign test accuracy: 0.8
# Current benign test loss: 0.8422136902809143
# Current adversarial test accuracy: 0.33
# Current adversarial test loss: 1.8234193325042725
#
# Current batch: 10
# Current benign test accuracy: 0.75
# Current benign test loss: 0.8585765361785889
# Current adversarial test accuracy: 0.34
# Current adversarial test loss: 1.851802110671997
#
# Current batch: 20
# Current benign test accuracy: 0.78
# Current benign test loss: 0.8618671298027039
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 1.820149540901184
#
# Current batch: 30
# Current benign test accuracy: 0.77
# Current benign test loss: 0.8823845386505127
# Current adversarial test accuracy: 0.35
# Current adversarial test loss: 1.8252464532852173
#
# Current batch: 40
# Current benign test accuracy: 0.76
# Current benign test loss: 0.8443019986152649
# Current adversarial test accuracy: 0.36
# Current adversarial test loss: 1.8570778369903564
#
# Current batch: 50
# Current benign test accuracy: 0.84
# Current benign test loss: 0.8296568989753723
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 1.886483907699585
#
# Current batch: 60
# Current benign test accuracy: 0.74
# Current benign test loss: 0.9238038063049316
# Current adversarial test accuracy: 0.26
# Current adversarial test loss: 1.9174106121063232
#
# Current batch: 70
# Current benign test accuracy: 0.74
# Current benign test loss: 0.8598504066467285
# Current adversarial test accuracy: 0.35
# Current adversarial test loss: 1.8701852560043335
#
# Current batch: 80
# Current benign test accuracy: 0.79
# Current benign test loss: 0.8486752510070801
# Current adversarial test accuracy: 0.29
# Current adversarial test loss: 1.871885061264038
#
# Current batch: 90
# Current benign test accuracy: 0.83
# Current benign test loss: 0.7673269510269165
# Current adversarial test accuracy: 0.28
# Current adversarial test loss: 1.8209724426269531
#
# Total benign test accuarcy: 78.46
# Total adversarial test Accuarcy: 29.82
# Total benign test loss: 85.31220144033432
# Total adversarial test loss: 186.3773317337036
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 1.2763671875
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 2.14156174659729
#
# Current batch: 10
# Current benign train accuracy: 0.1328125
# Current benign train loss: 1.1952204704284668
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 1.7622476816177368
#
# Current batch: 20
# Current benign train accuracy: 0.1796875
# Current benign train loss: 1.6284608840942383
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.016786575317383
#
# Current batch: 30
# Current benign train accuracy: 0.078125
# Current benign train loss: 0.9870456457138062
# Current adversarial train accuracy: 0.234375
# Current adversarial train loss: 2.0570387840270996
#
# Current batch: 40
# Current benign train accuracy: 0.1328125
# Current benign train loss: 0.8922394514083862
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 2.171964645385742
#
# Current batch: 50
# Current benign train accuracy: 0.0859375
# Current benign train loss: 1.2392566204071045
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 1.9928390979766846
#
# Current batch: 60
# Current benign train accuracy: 0.0703125
# Current benign train loss: 1.152734398841858
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.9695459604263306
#
# Current batch: 70
# Current benign train accuracy: 0.7734375
# Current benign train loss: 1.305731177330017
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 1.764887809753418
#
# Current batch: 80
# Current benign train accuracy: 0.7265625
# Current benign train loss: 1.505751132965088
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 2.0409250259399414
#
# Current batch: 90
# Current benign train accuracy: 0.84375
# Current benign train loss: 1.0216509103775024
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 1.9067670106887817
#
# Current batch: 100
# Current benign train accuracy: 0.3359375
# Current benign train loss: 1.726906657218933
# Current adversarial train accuracy: 0.0703125
# Current adversarial train loss: 1.8569910526275635
#
# Current batch: 110
# Current benign train accuracy: 0.796875
# Current benign train loss: 1.1333287954330444
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 1.8458797931671143
#
# Current batch: 120
# Current benign train accuracy: 0.140625
# Current benign train loss: 1.6541640758514404
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 2.0146820545196533
#
# Current batch: 130
# Current benign train accuracy: 0.7109375
# Current benign train loss: 1.5809755325317383
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 1.9719884395599365
#
# Current batch: 140
# Current benign train accuracy: 0.3515625
# Current benign train loss: 1.765371561050415
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 2.0441198348999023
#
# Current batch: 150
# Current benign train accuracy: 0.09375
# Current benign train loss: 1.0978174209594727
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.7517869472503662
#
# Current batch: 160
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.8611065149307251
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 1.9325048923492432
#
# Current batch: 170
# Current benign train accuracy: 0.171875
# Current benign train loss: 1.6993192434310913
# Current adversarial train accuracy: 0.109375
# Current adversarial train loss: 2.01796555519104
#
# Current batch: 180
# Current benign train accuracy: 0.1640625
# Current benign train loss: 1.7796478271484375
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.1706056594848633
#
# Current batch: 190
# Current benign train accuracy: 0.1015625
# Current benign train loss: 1.3364568948745728
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.9151074886322021
#
# Current batch: 200
# Current benign train accuracy: 0.1328125
# Current benign train loss: 0.921195924282074
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.9359729290008545
#
# Current batch: 210
# Current benign train accuracy: 0.234375
# Current benign train loss: 1.6889594793319702
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 1.9996205568313599
#
# Current batch: 220
# Current benign train accuracy: 0.1328125
# Current benign train loss: 1.6115033626556396
# Current adversarial train accuracy: 0.0703125
# Current adversarial train loss: 2.213454246520996
#
# Current batch: 230
# Current benign train accuracy: 0.7421875
# Current benign train loss: 1.4517595767974854
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.0318374633789062
#
# Current batch: 240
# Current benign train accuracy: 0.125
# Current benign train loss: 1.4660966396331787
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 1.8632694482803345
#
# Current batch: 250
# Current benign train accuracy: 0.1015625
# Current benign train loss: 1.2548058032989502
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 2.0752105712890625
#
# Current batch: 260
# Current benign train accuracy: 0.140625
# Current benign train loss: 1.5665383338928223
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 1.9047037363052368
#
# Current batch: 270
# Current benign train accuracy: 0.3046875
# Current benign train loss: 1.787906289100647
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 1.8544676303863525
#
# Current batch: 280
# Current benign train accuracy: 0.2265625
# Current benign train loss: 1.6881215572357178
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 2.013474941253662
#
# Current batch: 290
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.6779199838638306
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 2.1161255836486816
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 1.5042848587036133
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 1.9575624465942383
#
# Current batch: 310
# Current benign train accuracy: 0.109375
# Current benign train loss: 1.434778094291687
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 1.8446099758148193
#
# Current batch: 320
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.701017141342163
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.9605116844177246
#
# Current batch: 330
# Current benign train accuracy: 0.8046875
# Current benign train loss: 1.2955514192581177
# Current adversarial train accuracy: 0.09375
# Current adversarial train loss: 1.9242651462554932
#
# Current batch: 340
# Current benign train accuracy: 0.71875
# Current benign train loss: 1.5346782207489014
# Current adversarial train accuracy: 0.25
# Current adversarial train loss: 2.1221532821655273
#
# Current batch: 350
# Current benign train accuracy: 0.21875
# Current benign train loss: 1.6245536804199219
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.9802746772766113
#
# Current batch: 360
# Current benign train accuracy: 0.125
# Current benign train loss: 1.6378173828125
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 2.011908531188965
#
# Current batch: 370
# Current benign train accuracy: 0.1640625
# Current benign train loss: 1.6159319877624512
# Current adversarial train accuracy: 0.28125
# Current adversarial train loss: 1.9048316478729248
#
# Current batch: 380
# Current benign train accuracy: 0.0625
# Current benign train loss: 1.3139047622680664
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 2.0261669158935547
#
# Current batch: 390
# Current benign train accuracy: 0.425
# Current benign train loss: 1.7818714380264282
# Current adversarial train accuracy: 0.4125
# Current adversarial train loss: 2.021024227142334
#
# Total benign train accuarcy: tensor(59.8096, device='cuda:0')
# Total adversarial train accuarcy: tensor(28.3950, device='cuda:0')
# Total benign train loss: 547.4903510808945
# Total adversarial train loss: 772.9529085159302
#
# [ Test epoch: 1 ]
#
# Current batch: 0
# Current benign test accuracy: 0.81
# Current benign test loss: 0.798777163028717
# Current adversarial test accuracy: 0.33
# Current adversarial test loss: 1.7536224126815796
#
# Current batch: 10
# Current benign test accuracy: 0.79
# Current benign test loss: 0.816791832447052
# Current adversarial test accuracy: 0.38
# Current adversarial test loss: 1.7959010601043701
#
# Current batch: 20
# Current benign test accuracy: 0.8
# Current benign test loss: 0.8028736114501953
# Current adversarial test accuracy: 0.3
# Current adversarial test loss: 1.6943135261535645
#
# Current batch: 30
# Current benign test accuracy: 0.79
# Current benign test loss: 0.825441300868988
# Current adversarial test accuracy: 0.37
# Current adversarial test loss: 1.6977061033248901
#
# Current batch: 40
# Current benign test accuracy: 0.83
# Current benign test loss: 0.7846864461898804
# Current adversarial test accuracy: 0.34
# Current adversarial test loss: 1.7690682411193848
#
# Current batch: 50
# Current benign test accuracy: 0.89
# Current benign test loss: 0.7727019786834717
# Current adversarial test accuracy: 0.29
# Current adversarial test loss: 1.794493556022644
#
# Current batch: 60
# Current benign test accuracy: 0.78
# Current benign test loss: 0.8790701031684875
# Current adversarial test accuracy: 0.28
# Current adversarial test loss: 1.8354911804199219
#
# Current batch: 70
# Current benign test accuracy: 0.77
# Current benign test loss: 0.8149650692939758
# Current adversarial test accuracy: 0.41
# Current adversarial test loss: 1.7429211139678955
#
# Current batch: 80
# Current benign test accuracy: 0.82
# Current benign test loss: 0.8108218908309937
# Current adversarial test accuracy: 0.34
# Current adversarial test loss: 1.7567036151885986
#
# Current batch: 90
# Current benign test accuracy: 0.86
# Current benign test loss: 0.7265582084655762
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 1.6925610303878784
#
# Total benign test accuarcy: 81.39
# Total adversarial test Accuarcy: 32.9
# Total benign test loss: 80.72668451070786
# Total adversarial test loss: 176.393905043602
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4140625
# Current benign train loss: 1.665540337562561
# Current adversarial train accuracy: 0.2578125
# Current adversarial train loss: 2.0503997802734375
#
# Current batch: 10
# Current benign train accuracy: 0.4609375
# Current benign train loss: 1.7004528045654297
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.8988367319107056
#
# Current batch: 20
# Current benign train accuracy: 0.5546875
# Current benign train loss: 1.6624329090118408
# Current adversarial train accuracy: 0.0859375
# Current adversarial train loss: 1.8215924501419067
#
# Current batch: 30
# Current benign train accuracy: 0.7265625
# Current benign train loss: 1.5182106494903564
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.7979180812835693
#
# Current batch: 40
# Current benign train accuracy: 0.078125
# Current benign train loss: 1.5730173587799072
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 2.0794525146484375
#
# Current batch: 50
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.8132089376449585
# Current adversarial train accuracy: 0.078125
# Current adversarial train loss: 1.8570377826690674
#
# Current batch: 60
# Current benign train accuracy: 0.7734375
# Current benign train loss: 1.051088809967041
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.0673880577087402
#
# Current batch: 70
# Current benign train accuracy: 0.390625
# Current benign train loss: 1.7828612327575684
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 2.037170886993408
#
# Current batch: 80
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.9433367252349854
# Current adversarial train accuracy: 0.0703125
# Current adversarial train loss: 1.928999423980713
#
# Current batch: 90
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.6329002380371094
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 1.8718432188034058
#
# Current batch: 100
# Current benign train accuracy: 0.328125
# Current benign train loss: 1.7319413423538208
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 1.9722331762313843
#
# Current batch: 110
# Current benign train accuracy: 0.8125
# Current benign train loss: 1.1649081707000732
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 2.1082584857940674
#
# Current batch: 120
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.7054510116577148
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.9104101657867432
#
# Current batch: 130
# Current benign train accuracy: 0.1875
# Current benign train loss: 1.6411399841308594
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 2.077026844024658
#
# Current batch: 140
# Current benign train accuracy: 0.0859375
# Current benign train loss: 0.7460774779319763
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 1.981400966644287
#
# Current batch: 150
# Current benign train accuracy: 0.328125
# Current benign train loss: 1.7588911056518555
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 2.1141295433044434
#
# Current batch: 160
# Current benign train accuracy: 0.09375
# Current benign train loss: 1.5035431385040283
# Current adversarial train accuracy: 0.078125
# Current adversarial train loss: 1.9713969230651855
#
# Current batch: 170
# Current benign train accuracy: 0.8359375
# Current benign train loss: 1.2243075370788574
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 1.868184208869934
#
# Current batch: 180
# Current benign train accuracy: 0.6640625
# Current benign train loss: 1.6479864120483398
# Current adversarial train accuracy: 0.0859375
# Current adversarial train loss: 1.9740452766418457
#
# Current batch: 190
# Current benign train accuracy: 0.6875
# Current benign train loss: 1.5829747915267944
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 2.0122263431549072
#
# Current batch: 200
# Current benign train accuracy: 0.0703125
# Current benign train loss: 1.0262300968170166
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 1.8433399200439453
#
# Current batch: 210
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.6479547023773193
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.952134370803833
#
# Current batch: 220
# Current benign train accuracy: 0.4609375
# Current benign train loss: 1.6997158527374268
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 1.8374449014663696
#
# Current batch: 230
# Current benign train accuracy: 0.1640625
# Current benign train loss: 1.8091812133789062
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.1016275882720947
#
# Current batch: 240
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.9460644721984863
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 1.9174506664276123
#
# Current batch: 250
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.9560463428497314
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 2.047889232635498
#
# Current batch: 260
# Current benign train accuracy: 0.1015625
# Current benign train loss: 0.8791552782058716
# Current adversarial train accuracy: 0.09375
# Current adversarial train loss: 1.877439022064209
#
# Current batch: 270
# Current benign train accuracy: 0.71875
# Current benign train loss: 1.5486618280410767
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.7480010986328125
#
# Current batch: 280
# Current benign train accuracy: 0.1171875
# Current benign train loss: 1.4236044883728027
# Current adversarial train accuracy: 0.4140625
# Current adversarial train loss: 1.8659793138504028
#
# Current batch: 290
# Current benign train accuracy: 0.671875
# Current benign train loss: 1.6082019805908203
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 2.0293445587158203
#
# Current batch: 300
# Current benign train accuracy: 0.484375
# Current benign train loss: 1.7556171417236328
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 1.9040862321853638
#
# Current batch: 310
# Current benign train accuracy: 0.1171875
# Current benign train loss: 1.2955553531646729
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 2.0779552459716797
#
# Current batch: 320
# Current benign train accuracy: 0.296875
# Current benign train loss: 1.6693469285964966
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.8841638565063477
#
# Current batch: 330
# Current benign train accuracy: 0.7890625
# Current benign train loss: 1.4982222318649292
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.9015419483184814
#
# Current batch: 340
# Current benign train accuracy: 0.71875
# Current benign train loss: 1.3377948999404907
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 2.0503334999084473
#
# Current batch: 350
# Current benign train accuracy: 0.265625
# Current benign train loss: 1.6301437616348267
# Current adversarial train accuracy: 0.109375
# Current adversarial train loss: 1.940732479095459
#
# Current batch: 360
# Current benign train accuracy: 0.125
# Current benign train loss: 1.388787031173706
# Current adversarial train accuracy: 0.0859375
# Current adversarial train loss: 1.8327765464782715
#
# Current batch: 370
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.802085816860199
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 1.7300193309783936
#
# Current batch: 380
# Current benign train accuracy: 0.109375
# Current benign train loss: 1.162480354309082
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 2.124532461166382
#
# Current batch: 390
# Current benign train accuracy: 0.825
# Current benign train loss: 1.0693833827972412
# Current adversarial train accuracy: 0.15
# Current adversarial train loss: 2.0671846866607666
#
# Total benign train accuarcy: tensor(61.0479, device='cuda:0')
# Total adversarial train accuarcy: tensor(29.9762, device='cuda:0')
# Total benign train loss: 534.619088768959
# Total adversarial train loss: 762.6286435127258
#
# [ Test epoch: 2 ]
#
# Current batch: 0
# Current benign test accuracy: 0.84
# Current benign test loss: 0.8045427203178406
# Current adversarial test accuracy: 0.31
# Current adversarial test loss: 1.7994388341903687
#
# Current batch: 10
# Current benign test accuracy: 0.83
# Current benign test loss: 0.7884540557861328
# Current adversarial test accuracy: 0.34
# Current adversarial test loss: 1.8129621744155884
#
# Current batch: 20
# Current benign test accuracy: 0.78
# Current benign test loss: 0.8029129505157471
# Current adversarial test accuracy: 0.38
# Current adversarial test loss: 1.7077451944351196
#
# Current batch: 30
# Current benign test accuracy: 0.81
# Current benign test loss: 0.8454281687736511
# Current adversarial test accuracy: 0.35
# Current adversarial test loss: 1.7875555753707886
#
# Current batch: 40
# Current benign test accuracy: 0.81
# Current benign test loss: 0.7771791815757751
# Current adversarial test accuracy: 0.37
# Current adversarial test loss: 1.7737551927566528
#
# Current batch: 50
# Current benign test accuracy: 0.85
# Current benign test loss: 0.7542551159858704
# Current adversarial test accuracy: 0.33
# Current adversarial test loss: 1.7919772863388062
#
# Current batch: 60
# Current benign test accuracy: 0.82
# Current benign test loss: 0.846676230430603
# Current adversarial test accuracy: 0.24
# Current adversarial test loss: 1.8495537042617798
#
# Current batch: 70
# Current benign test accuracy: 0.78
# Current benign test loss: 0.8181402683258057
# Current adversarial test accuracy: 0.41
# Current adversarial test loss: 1.7834707498550415
#
# Current batch: 80
# Current benign test accuracy: 0.85
# Current benign test loss: 0.7706272006034851
# Current adversarial test accuracy: 0.34
# Current adversarial test loss: 1.7803539037704468
#
# Current batch: 90
# Current benign test accuracy: 0.89
# Current benign test loss: 0.689863383769989
# Current adversarial test accuracy: 0.31
# Current adversarial test loss: 1.6927859783172607
#
# Total benign test accuarcy: 81.63
# Total adversarial test Accuarcy: 32.83
# Total benign test loss: 79.58937537670135
# Total adversarial test loss: 179.49816489219666
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.1328125
# Current benign train loss: 1.565434217453003
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.000091314315796
#
# Current batch: 10
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.7336974143981934
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.8424100875854492
#
# Current batch: 20
# Current benign train accuracy: 0.8515625
# Current benign train loss: 1.1398289203643799
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 2.0704731941223145
#
# Current batch: 30
# Current benign train accuracy: 0.265625
# Current benign train loss: 1.7894208431243896
# Current adversarial train accuracy: 0.0859375
# Current adversarial train loss: 1.892653465270996
#
# Current batch: 40
# Current benign train accuracy: 0.625
# Current benign train loss: 1.701064109802246
# Current adversarial train accuracy: 0.046875
# Current adversarial train loss: 1.8297092914581299
#
# Current batch: 50
# Current benign train accuracy: 0.125
# Current benign train loss: 1.1559040546417236
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 2.0295228958129883
#
# Current batch: 60
# Current benign train accuracy: 0.140625
# Current benign train loss: 1.446149230003357
# Current adversarial train accuracy: 0.0625
# Current adversarial train loss: 1.8465471267700195
#
# Current batch: 70
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.9267137050628662
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 1.9894461631774902
#
# Current batch: 80
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.735067367553711
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 2.091998338699341
#
# Current batch: 90
# Current benign train accuracy: 0.1171875
# Current benign train loss: 1.40773606300354
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.1212315559387207
#
# Current batch: 100
# Current benign train accuracy: 0.140625
# Current benign train loss: 1.517308235168457
# Current adversarial train accuracy: 0.2890625
# Current adversarial train loss: 2.236854076385498
#
# Current batch: 110
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.6185907125473022
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 1.9445946216583252
#
# Current batch: 120
# Current benign train accuracy: 0.734375
# Current benign train loss: 1.6516237258911133
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 1.7332916259765625
#
# Current batch: 130
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.772680938243866
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 1.982548475265503
#
# Current batch: 140
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.7341089248657227
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.006503105163574
#
# Current batch: 150
# Current benign train accuracy: 0.8125
# Current benign train loss: 1.2556849718093872
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 1.9752047061920166
#
# Current batch: 160
# Current benign train accuracy: 0.09375
# Current benign train loss: 1.3476526737213135
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 1.9308581352233887
#
# Current batch: 170
# Current benign train accuracy: 0.0546875
# Current benign train loss: 0.9893018007278442
# Current adversarial train accuracy: 0.2734375
# Current adversarial train loss: 2.0471675395965576
#
# Current batch: 180
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.7797881364822388
# Current adversarial train accuracy: 0.078125
# Current adversarial train loss: 2.061824321746826
#
# Current batch: 190
# Current benign train accuracy: 0.1171875
# Current benign train loss: 1.5550682544708252
# Current adversarial train accuracy: 0.109375
# Current adversarial train loss: 1.9881393909454346
#
# Current batch: 200
# Current benign train accuracy: 0.171875
# Current benign train loss: 1.2710678577423096
# Current adversarial train accuracy: 0.09375
# Current adversarial train loss: 2.0319275856018066
#
# Current batch: 210
# Current benign train accuracy: 0.3984375
# Current benign train loss: 1.8079321384429932
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 1.9860666990280151
#
# Current batch: 220
# Current benign train accuracy: 0.5390625
# Current benign train loss: 1.7554261684417725
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 2.0062031745910645
#
# Current batch: 230
# Current benign train accuracy: 0.1484375
# Current benign train loss: 0.8433627486228943
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 1.9106742143630981
#
# Current batch: 240
# Current benign train accuracy: 0.765625
# Current benign train loss: 1.4741448163986206
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 1.7912242412567139
#
# Current batch: 250
# Current benign train accuracy: 0.8203125
# Current benign train loss: 1.076668620109558
# Current adversarial train accuracy: 0.34375
# Current adversarial train loss: 1.8974440097808838
#
# Current batch: 260
# Current benign train accuracy: 0.125
# Current benign train loss: 1.5003249645233154
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 1.9459943771362305
#
# Current batch: 270
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.6229331493377686
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 1.7615647315979004
#
# Current batch: 280
# Current benign train accuracy: 0.7734375
# Current benign train loss: 1.3893213272094727
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 2.0345096588134766
#
# Current batch: 290
# Current benign train accuracy: 0.8203125
# Current benign train loss: 1.3785295486450195
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 2.009303092956543
#
# Current batch: 300
# Current benign train accuracy: 0.1796875
# Current benign train loss: 1.6246929168701172
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.0626840591430664
#
# Current batch: 310
# Current benign train accuracy: 0.078125
# Current benign train loss: 0.8384457230567932
# Current adversarial train accuracy: 0.296875
# Current adversarial train loss: 1.895019769668579
#
# Current batch: 320
# Current benign train accuracy: 0.828125
# Current benign train loss: 1.055243968963623
# Current adversarial train accuracy: 0.3984375
# Current adversarial train loss: 1.6288869380950928
#
# Current batch: 330
# Current benign train accuracy: 0.078125
# Current benign train loss: 1.0279521942138672
# Current adversarial train accuracy: 0.3046875
# Current adversarial train loss: 1.987074851989746
#
# Current batch: 340
# Current benign train accuracy: 0.125
# Current benign train loss: 0.7587161660194397
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 2.136000633239746
#
# Current batch: 350
# Current benign train accuracy: 0.1171875
# Current benign train loss: 1.679804801940918
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 1.910995364189148
#
# Current batch: 360
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.9342585802078247
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 1.886883020401001
#
# Current batch: 370
# Current benign train accuracy: 0.125
# Current benign train loss: 1.0880935192108154
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 1.9433326721191406
#
# Current batch: 380
# Current benign train accuracy: 0.2421875
# Current benign train loss: 1.7235859632492065
# Current adversarial train accuracy: 0.0859375
# Current adversarial train loss: 2.1188430786132812
#
# Current batch: 390
# Current benign train accuracy: 0.175
# Current benign train loss: 1.5375421047210693
# Current adversarial train accuracy: 0.1375
# Current adversarial train loss: 2.0118026733398438
#
# Total benign train accuarcy: tensor(62.7157, device='cuda:0')
# Total adversarial train accuarcy: tensor(30.9181, device='cuda:0')
# Total benign train loss: 514.9959512352943
# Total adversarial train loss: 755.4249973297119
#
# [ Test epoch: 3 ]
#
# Current batch: 0
# Current benign test accuracy: 0.86
# Current benign test loss: 0.7172219753265381
# Current adversarial test accuracy: 0.36
# Current adversarial test loss: 1.7267624139785767
#
# Current batch: 10
# Current benign test accuracy: 0.81
# Current benign test loss: 0.7712453603744507
# Current adversarial test accuracy: 0.36
# Current adversarial test loss: 1.8221861124038696
#
# Current batch: 20
# Current benign test accuracy: 0.79
# Current benign test loss: 0.7807049751281738
# Current adversarial test accuracy: 0.31
# Current adversarial test loss: 1.717360258102417
#
# Current batch: 30
# Current benign test accuracy: 0.79
# Current benign test loss: 0.7916426062583923
# Current adversarial test accuracy: 0.37
# Current adversarial test loss: 1.7488234043121338
#
# Current batch: 40
# Current benign test accuracy: 0.84
# Current benign test loss: 0.7403724193572998
# Current adversarial test accuracy: 0.34
# Current adversarial test loss: 1.753959059715271
#
# Current batch: 50
# Current benign test accuracy: 0.9
# Current benign test loss: 0.6890360116958618
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 1.7471346855163574
#
# Current batch: 60
# Current benign test accuracy: 0.76
# Current benign test loss: 0.8506760597229004
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 1.90724778175354
#
# Current batch: 70
# Current benign test accuracy: 0.79
# Current benign test loss: 0.7874742150306702
# Current adversarial test accuracy: 0.42
# Current adversarial test loss: 1.762434959411621
#
# Current batch: 80
# Current benign test accuracy: 0.82
# Current benign test loss: 0.7425387501716614
# Current adversarial test accuracy: 0.32
# Current adversarial test loss: 1.7968521118164062
#
# Current batch: 90
# Current benign test accuracy: 0.85
# Current benign test loss: 0.6784640550613403
# Current adversarial test accuracy: 0.34
# Current adversarial test loss: 1.7124727964401245
#
# Total benign test accuarcy: 82.93
# Total adversarial test Accuarcy: 33.71
# Total benign test loss: 75.50933355093002
# Total adversarial test loss: 178.04791629314423
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.1171875
# Current benign train loss: 1.295676589012146
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.8628708124160767
#
# Current batch: 10
# Current benign train accuracy: 0.5390625
# Current benign train loss: 1.7016276121139526
# Current adversarial train accuracy: 0.375
# Current adversarial train loss: 1.9104729890823364
#
# Current batch: 20
# Current benign train accuracy: 0.6796875
# Current benign train loss: 1.6266818046569824
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 1.9046140909194946
#
# Current batch: 30
# Current benign train accuracy: 0.8515625
# Current benign train loss: 1.3236891031265259
# Current adversarial train accuracy: 0.5390625
# Current adversarial train loss: 1.7416222095489502
#
# Current batch: 40
# Current benign train accuracy: 0.75
# Current benign train loss: 1.5475525856018066
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 2.0896968841552734
#
# Current batch: 50
# Current benign train accuracy: 0.4453125
# Current benign train loss: 1.7725458145141602
# Current adversarial train accuracy: 0.0703125
# Current adversarial train loss: 1.7882955074310303
#
# Current batch: 60
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.6325335502624512
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 1.6510701179504395
#
# Current batch: 70
# Current benign train accuracy: 0.1171875
# Current benign train loss: 0.7611489295959473
# Current adversarial train accuracy: 0.109375
# Current adversarial train loss: 1.8689974546432495
#
# Current batch: 80
# Current benign train accuracy: 0.0625
# Current benign train loss: 1.3452293872833252
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 1.9662889242172241
#
# Current batch: 90
# Current benign train accuracy: 0.4765625
# Current benign train loss: 1.742997407913208
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 2.0286777019500732
#
# Current batch: 100
# Current benign train accuracy: 0.2578125
# Current benign train loss: 1.507779836654663
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 1.5211328268051147
#
# Current batch: 110
# Current benign train accuracy: 0.15625
# Current benign train loss: 1.6315643787384033
# Current adversarial train accuracy: 0.3359375
# Current adversarial train loss: 1.8750035762786865
#
# Current batch: 120
# Current benign train accuracy: 0.5546875
# Current benign train loss: 1.6951820850372314
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 1.8665187358856201
#
# Current batch: 130
# Current benign train accuracy: 0.15625
# Current benign train loss: 0.7923400402069092
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.5504902601242065
#
# Current batch: 140
# Current benign train accuracy: 0.2578125
# Current benign train loss: 1.699864149093628
# Current adversarial train accuracy: 0.3515625
# Current adversarial train loss: 2.074065923690796
#
# Current batch: 150
# Current benign train accuracy: 0.2890625
# Current benign train loss: 1.7269179821014404
# Current adversarial train accuracy: 0.3203125
# Current adversarial train loss: 2.062007188796997
#
# Current batch: 160
# Current benign train accuracy: 0.8359375
# Current benign train loss: 1.0710437297821045
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 2.0465023517608643
#
# Current batch: 170
# Current benign train accuracy: 0.8125
# Current benign train loss: 1.1637604236602783
# Current adversarial train accuracy: 0.3125
# Current adversarial train loss: 2.0069024562835693
#
# Current batch: 180
# Current benign train accuracy: 0.15625
# Current benign train loss: 1.4954190254211426
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 2.072373390197754
#
# Current batch: 190
# Current benign train accuracy: 0.7421875
# Current benign train loss: 1.2766079902648926
# Current adversarial train accuracy: 0.078125
# Current adversarial train loss: 2.0155348777770996
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 1.4434254169464111
# Current adversarial train accuracy: 0.328125
# Current adversarial train loss: 2.011655330657959
#
# Current batch: 210
# Current benign train accuracy: 0.0859375
# Current benign train loss: 1.0286439657211304
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 1.7654974460601807
#
# Current batch: 220
# Current benign train accuracy: 0.109375
# Current benign train loss: 0.90044105052948
# Current adversarial train accuracy: 0.09375
# Current adversarial train loss: 1.937233567237854
#
# Current batch: 230
# Current benign train accuracy: 0.8203125
# Current benign train loss: 1.4842376708984375
# Current adversarial train accuracy: 0.4453125
# Current adversarial train loss: 1.7881159782409668
#
# Current batch: 240
# Current benign train accuracy: 0.7109375
# Current benign train loss: 1.6080243587493896
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.8391956090927124
#
# Current batch: 250
# Current benign train accuracy: 0.09375
# Current benign train loss: 1.2365930080413818
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 2.1223196983337402
#
# Current batch: 260
# Current benign train accuracy: 0.53125
# Current benign train loss: 1.712573766708374
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 1.9484927654266357
#
# Current batch: 270
# Current benign train accuracy: 0.4296875
# Current benign train loss: 1.6543407440185547
# Current adversarial train accuracy: 0.3828125
# Current adversarial train loss: 1.7995585203170776
#
# Current batch: 280
# Current benign train accuracy: 0.1875
# Current benign train loss: 1.7582192420959473
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 2.14506196975708
#
# Current batch: 290
# Current benign train accuracy: 0.203125
# Current benign train loss: 1.6891851425170898
# Current adversarial train accuracy: 0.265625
# Current adversarial train loss: 1.9374775886535645
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 1.0003381967544556
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 2.1384005546569824
#
# Current batch: 310
# Current benign train accuracy: 0.71875
# Current benign train loss: 1.523752212524414
# Current adversarial train accuracy: 0.109375
# ...
# Current adversarial train loss: 1.6997685432434082
#
# Current batch: 240
# Current benign train accuracy: 0.4296875
# Current benign train loss: 1.3347991704940796
# Current adversarial train accuracy: 0.09375
# Current adversarial train loss: 1.2676187753677368
#
# Current batch: 250
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.3593206405639648
# Current adversarial train accuracy: 0.3671875
# Current adversarial train loss: 1.705876111984253
#
# Current batch: 260
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.6740714311599731
# Current adversarial train accuracy: 0.546875
# Current adversarial train loss: 1.6193177700042725
#
# Current batch: 270
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.4069468975067139
# Current adversarial train accuracy: 0.6015625
# Current adversarial train loss: 1.3531036376953125
#
# Current batch: 280
# Current benign train accuracy: 0.0546875
# Current benign train loss: 0.32428282499313354
# Current adversarial train accuracy: 0.390625
# Current adversarial train loss: 1.7276501655578613
#
# Current batch: 290
# Current benign train accuracy: 0.0859375
# Current benign train loss: 0.7417634725570679
# Current adversarial train accuracy: 0.7265625
# Current adversarial train loss: 1.4436993598937988
#
# Current batch: 300
# Current benign train accuracy: 0.1171875
# Current benign train loss: 0.7847638130187988
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 1.6721227169036865
#
# Current batch: 310
# Current benign train accuracy: 0.375
# Current benign train loss: 1.4192488193511963
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 1.5721840858459473
#
# Current batch: 320
# Current benign train accuracy: 0.0546875
# Current benign train loss: 0.4303101897239685
# Current adversarial train accuracy: 0.2109375
# Current adversarial train loss: 1.6959033012390137
#
# Current batch: 330
# Current benign train accuracy: 0.0625
# Current benign train loss: 0.6270347237586975
# Current adversarial train accuracy: 0.546875
# Current adversarial train loss: 1.3555546998977661
#
# Current batch: 340
# Current benign train accuracy: 0.1796875
# Current benign train loss: 1.1767277717590332
# Current adversarial train accuracy: 0.109375
# Current adversarial train loss: 1.2776738405227661
#
# Current batch: 350
# Current benign train accuracy: 0.2265625
# Current benign train loss: 1.2915680408477783
# Current adversarial train accuracy: 0.0859375
# Current adversarial train loss: 1.4783446788787842
#
# Current batch: 360
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.7309328317642212
# Current adversarial train accuracy: 0.6015625
# Current adversarial train loss: 1.3898195028305054
#
# Current batch: 370
# Current benign train accuracy: 0.1171875
# Current benign train loss: 0.8246246576309204
# Current adversarial train accuracy: 0.578125
# Current adversarial train loss: 1.5691078901290894
#
# Current batch: 380
# Current benign train accuracy: 0.15625
# Current benign train loss: 1.0680174827575684
# Current adversarial train accuracy: 0.6953125
# Current adversarial train loss: 0.8463768362998962
#
# Current batch: 390
# Current benign train accuracy: 0.925
# Current benign train loss: 1.1711249351501465
# Current adversarial train accuracy: 0.1375
# Current adversarial train loss: 1.5306103229522705
#
# Total benign train accuarcy: tensor(73.5197, device='cuda:0')
# Total adversarial train accuarcy: tensor(48.9133, device='cuda:0')
# Total benign train loss: 375.9409842789173
# Total adversarial train loss: 577.9024832248688
#
# [ Test epoch: 73 ]
#
# Current batch: 0
# Current benign test accuracy: 0.92
# Current benign test loss: 0.37849971652030945
# Current adversarial test accuracy: 0.38
# Current adversarial test loss: 1.7403515577316284
#
# Current batch: 10
# Current benign test accuracy: 0.92
# Current benign test loss: 0.3903292715549469
# Current adversarial test accuracy: 0.41
# Current adversarial test loss: 1.7183150053024292
#
# Current batch: 20
# Current benign test accuracy: 0.89
# Current benign test loss: 0.44510966539382935
# Current adversarial test accuracy: 0.42
# Current adversarial test loss: 1.7538659572601318
#
# Current batch: 30
# Current benign test accuracy: 0.91
# Current benign test loss: 0.41716983914375305
# Current adversarial test accuracy: 0.44
# Current adversarial test loss: 1.6631981134414673
#
# Current batch: 40
# Current benign test accuracy: 0.87
# Current benign test loss: 0.44263285398483276
# Current adversarial test accuracy: 0.5
# Current adversarial test loss: 1.6282858848571777
#
# Current batch: 50
# Current benign test accuracy: 0.93
# Current benign test loss: 0.35305073857307434
# Current adversarial test accuracy: 0.41
# Current adversarial test loss: 1.711584210395813
#
# Current batch: 60
# Current benign test accuracy: 0.87
# Current benign test loss: 0.4695172905921936
# Current adversarial test accuracy: 0.34
# Current adversarial test loss: 1.9758785963058472
#
# Current batch: 70
# Current benign test accuracy: 0.86
# Current benign test loss: 0.46151939034461975
# Current adversarial test accuracy: 0.48
# Current adversarial test loss: 1.7413229942321777
#
# Current batch: 80
# Current benign test accuracy: 0.94
# Current benign test loss: 0.35926762223243713
# Current adversarial test accuracy: 0.46
# Current adversarial test loss: 1.6168065071105957
#
# Current batch: 90
# Current benign test accuracy: 0.94
# Current benign test loss: 0.3349921703338623
# Current adversarial test accuracy: 0.42
# Current adversarial test loss: 1.5788291692733765
#
# Total benign test accuarcy: 91.73
# Total adversarial test Accuarcy: 43.88
# Total benign test loss: 39.50888156890869
# Total adversarial test loss: 169.82975709438324
# Model Saved!
#
# [ Train epoch: 74 ]
#
# Current batch: 0
# Current benign train accuracy: 0.2578125
# Current benign train loss: 1.334741234779358
# Current adversarial train accuracy: 0.1796875
# Current adversarial train loss: 1.6742666959762573
#
# Current batch: 10
# Current benign train accuracy: 0.765625
# Current benign train loss: 1.3757715225219727
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 1.1749346256256104
#
# Current batch: 20
# Current benign train accuracy: 0.09375
# Current benign train loss: 1.08011794090271
# Current adversarial train accuracy: 0.1015625
# Current adversarial train loss: 1.5007665157318115
#
# Current batch: 30
# Current benign train accuracy: 0.6796875
# Current benign train loss: 1.3999539613723755
# Current adversarial train accuracy: 0.1875
# Current adversarial train loss: 1.4365230798721313
#
# Current batch: 40
# Current benign train accuracy: 0.9765625
# Current benign train loss: 1.0418434143066406
# Current adversarial train accuracy: 0.1484375
# Current adversarial train loss: 1.6620266437530518
#
# Current batch: 50
# Current benign train accuracy: 0.453125
# Current benign train loss: 1.2423827648162842
# Current adversarial train accuracy: 0.671875
# Current adversarial train loss: 1.4031118154525757
#
# Current batch: 60
# Current benign train accuracy: 0.9296875
# Current benign train loss: 1.0982205867767334
# Current adversarial train accuracy: 0.5703125
# Current adversarial train loss: 1.1821516752243042
#
# Current batch: 70
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.6235268115997314
# Current adversarial train accuracy: 0.15625
# Current adversarial train loss: 1.5870518684387207
#
# Current batch: 80
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.7258226871490479
# Current adversarial train accuracy: 0.0703125
# Current adversarial train loss: 1.4965314865112305
#
# Current batch: 90
# Current benign train accuracy: 0.109375
# Current benign train loss: 0.8378244042396545
# Current adversarial train accuracy: 0.53125
# Current adversarial train loss: 1.6976916790008545
#
# Current batch: 100
# Current benign train accuracy: 0.1015625
# Current benign train loss: 0.27936720848083496
# Current adversarial train accuracy: 0.2421875
# Current adversarial train loss: 1.6400458812713623
#
# Current batch: 110
# Current benign train accuracy: 0.1015625
# Current benign train loss: 0.5138640999794006
# Current adversarial train accuracy: 0.6328125
# Current adversarial train loss: 1.3692426681518555
#
# Current batch: 120
# Current benign train accuracy: 1.0
# Current benign train loss: 0.3920399844646454
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 1.300792932510376
#
# Current batch: 130
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.18368779122829437
# Current adversarial train accuracy: 0.140625
# Current adversarial train loss: 1.530656099319458
#
# Current batch: 140
# Current benign train accuracy: 0.3203125
# Current benign train loss: 1.2882239818572998
# Current adversarial train accuracy: 0.5703125
# Current adversarial train loss: 1.5505379438400269
#
# Current batch: 150
# Current benign train accuracy: 0.109375
# Current benign train loss: 0.8882594108581543
# Current adversarial train accuracy: 0.6015625
# Current adversarial train loss: 1.1949803829193115
#
# Current batch: 160
# Current benign train accuracy: 0.21875
# Current benign train loss: 1.3133081197738647
# Current adversarial train accuracy: 0.609375
# Current adversarial train loss: 0.9887915253639221
#
# Current batch: 170
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.6970996856689453
# Current adversarial train accuracy: 0.5703125
# Current adversarial train loss: 1.5651812553405762
#
# Current batch: 180
# Current benign train accuracy: 0.0859375
# Current benign train loss: 0.38608333468437195
# Current adversarial train accuracy: 0.6328125
# Current adversarial train loss: 1.2542939186096191
#
# Current batch: 190
# Current benign train accuracy: 0.953125
# Current benign train loss: 1.1482738256454468
# Current adversarial train accuracy: 0.6171875
# Current adversarial train loss: 1.463853359222412
#
# Current batch: 200
# Current benign train accuracy: 0.875
# Current benign train loss: 1.2744016647338867
# Current adversarial train accuracy: 0.578125
# Current adversarial train loss: 1.4445884227752686
#
# Current batch: 210
# Current benign train accuracy: 0.1015625
# Current benign train loss: 0.6302940845489502
# Current adversarial train accuracy: 0.1171875
# Current adversarial train loss: 1.6123028993606567
#
# Current batch: 220
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.4214850664138794
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 1.5591955184936523
#
# Current batch: 230
# Current benign train accuracy: 0.078125
# Current benign train loss: 1.0491563081741333
# Current adversarial train accuracy: 0.109375
# Current adversarial train loss: 1.315269947052002
#
# Current batch: 240
# Current benign train accuracy: 0.1875
# Current benign train loss: 1.3477225303649902
# Current adversarial train accuracy: 0.1953125
# Current adversarial train loss: 1.6065309047698975
#
# Current batch: 250
# Current benign train accuracy: 0.8984375
# Current benign train loss: 1.2500569820404053
# Current adversarial train accuracy: 0.5703125
# Current adversarial train loss: 1.597703456878662
#
# Current batch: 260
# Current benign train accuracy: 0.453125
# Current benign train loss: 1.42138671875
# Current adversarial train accuracy: 0.6171875
# Current adversarial train loss: 1.2847872972488403
#
# Current batch: 270
# Current benign train accuracy: 0.1015625
# Current benign train loss: 0.9987421035766602
# Current adversarial train accuracy: 0.5390625
# Current adversarial train loss: 1.6669933795928955
#
# Current batch: 280
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.8207045793533325
# Current adversarial train accuracy: 0.1328125
# Current adversarial train loss: 1.6099357604980469
#
# Current batch: 290
# Current benign train accuracy: 1.0
# Current benign train loss: 0.26217886805534363
# Current adversarial train accuracy: 0.1640625
# Current adversarial train loss: 1.6025564670562744
#
# Current batch: 300
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.7003943920135498
# Current adversarial train accuracy: 0.59375
# Current adversarial train loss: 1.6055586338043213
#
# Current batch: 310
# Current benign train accuracy: 0.2109375
# Current benign train loss: 1.4161810874938965
# Current adversarial train accuracy: 0.53125
# Current adversarial train loss: 1.6765706539154053
#
# Current batch: 320
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.5396663546562195
# Current adversarial train accuracy: 0.4296875
# Current adversarial train loss: 1.7200863361358643
#
# Current batch: 330
# Current benign train accuracy: 0.96875
# Current benign train loss: 1.0981711149215698
# Current adversarial train accuracy: 0.6875
# Current adversarial train loss: 1.464749813079834
#
# Current batch: 340
# Current benign train accuracy: 0.1171875
# Current benign train loss: 0.6082966923713684
# Current adversarial train accuracy: 0.2265625
# Current adversarial train loss: 1.8080881834030151
#
# Current batch: 350
# Current benign train accuracy: 0.1015625
# Current benign train loss: 1.1882418394088745
# Current adversarial train accuracy: 0.484375
# Current adversarial train loss: 1.6985461711883545
#
# Current batch: 360
# Current benign train accuracy: 0.3671875
# Current benign train loss: 1.2875707149505615
# Current adversarial train accuracy: 0.125
# Current adversarial train loss: 1.4566755294799805
#
# Current batch: 370
# Current benign train accuracy: 0.3828125
# Current benign train loss: 1.3803181648254395
# Current adversarial train accuracy: 0.203125
# Current adversarial train loss: 1.6940412521362305
#
# Current batch: 380
# Current benign train accuracy: 0.2109375
# Current benign train loss: 1.2854053974151611
# Current adversarial train accuracy: 0.59375
# Current adversarial train loss: 1.4581758975982666
#
# Current batch: 390
# Current benign train accuracy: 0.1375
# Current benign train loss: 1.090084433555603
# Current adversarial train accuracy: 0.6125
# Current adversarial train loss: 1.3131297826766968
#
# Total benign train accuarcy: tensor(74.3964, device='cuda:0')
# Total adversarial train accuarcy: tensor(49.0560, device='cuda:0')
# Total benign train loss: 365.98765905201435
# Total adversarial train loss: 575.062219619751
#
# [ Test epoch: 74 ]
#
# Current batch: 0
# Current benign test accuracy: 0.93
# Current benign test loss: 0.4413294196128845
# Current adversarial test accuracy: 0.43
# Current adversarial test loss: 1.4767755270004272
#
# Current batch: 10
# Current benign test accuracy: 0.93
# Current benign test loss: 0.4008720815181732
# Current adversarial test accuracy: 0.49
# Current adversarial test loss: 1.4645237922668457
#
# Current batch: 20
# Current benign test accuracy: 0.86
# Current benign test loss: 0.5143305659294128
# Current adversarial test accuracy: 0.43
# Current adversarial test loss: 1.547969937324524
#
# Current batch: 30
# Current benign test accuracy: 0.88
# Current benign test loss: 0.4767400026321411
# Current adversarial test accuracy: 0.51
# Current adversarial test loss: 1.4869778156280518
#
# Current batch: 40
# Current benign test accuracy: 0.87
# Current benign test loss: 0.4592943489551544
# Current adversarial test accuracy: 0.52
# Current adversarial test loss: 1.457189679145813
#
# Current batch: 50
# Current benign test accuracy: 0.93
# Current benign test loss: 0.40744057297706604
# Current adversarial test accuracy: 0.42
# Current adversarial test loss: 1.529349684715271
#
# Current batch: 60
# Current benign test accuracy: 0.82
# Current benign test loss: 0.5268049240112305
# Current adversarial test accuracy: 0.38
# Current adversarial test loss: 1.6940470933914185
#
# Current batch: 70
# Current benign test accuracy: 0.86
# Current benign test loss: 0.4692953824996948
# Current adversarial test accuracy: 0.51
# Current adversarial test loss: 1.539873480796814
#
# Current batch: 80
# Current benign test accuracy: 0.92
# Current benign test loss: 0.405422568321228
# Current adversarial test accuracy: 0.45
# Current adversarial test loss: 1.4676836729049683
#
# Current batch: 90
# Current benign test accuracy: 0.9
# Current benign test loss: 0.380776047706604
# Current adversarial test accuracy: 0.42
# Current adversarial test loss: 1.4091159105300903
#
# Total benign test accuarcy: 90.31
# Total adversarial test Accuarcy: 45.68
# Total benign test loss: 43.925084590911865
# Total adversarial test loss: 150.27090871334076
# Model Saved!

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion * planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])
def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
net = ResNet18()
net = net.to(device)
cudnn.benchmark = True
checkpoint = torch.load('./checkpoint/' + file_name)
net.load_state_dict(checkpoint['net'])
# Out:
# <All keys matched successfully>

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
])
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
test_loader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
l = [x for (x, y) in test_loader]
x_test = torch.cat(l, 0)
l = [y for (x, y) in test_loader]
y_test = torch.cat(l, 0)
# Out:
# Files already downloaded and verified

# %%
def eval_test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, size_average=False).item()
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    print('Test: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    test_accuracy = correct / len(test_loader.dataset)
    return test_loss, test_accuracy
eval_test(net, device, test_loader)
# Out:
# C:\Users\zahra\anaconda3\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test: Average loss: 0.3302, Accuracy: 9232/10000 (92%)
# (0.3301501514434814, 0.9232)

# %%
# !pip install git+https://github.com/fra31/auto-attack
# Out:
# Collecting git+https://github.com/fra31/auto-attack
#   Cloning https://github.com/fra31/auto-attack to c:\users\zahra\appdata\local\temp\pip-req-build-m803t32k
#   Resolved https://github.com/fra31/auto-attack to commit a39220048b3c9f2cca9a4d3a54604793c68eca7e
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Running command git clone --filter=blob:none --quiet https://github.com/fra31/auto-attack 'C:\Users\zahra\AppData\Local\Temp\pip-req-build-m803t32k'

# %%
from autoattack import AutoAttack
adversary = AutoAttack(net, norm='Linf', eps=0.031, version='standard')
# Out:
# setting parameters for standard version

# %%
adv_complete = adversary.run_standard_evaluation(x_test, y_test,bs=100)
# Out:
# using standard version including apgd-ce, apgd-t, fab-t, square.
# initial accuracy: 91.59%
# apgd-ce - 1/92 - 68 out of 100 successfully perturbed
# apgd-ce - 2/92 - 72 out of 100 successfully perturbed
# apgd-ce - 3/92 - 66 out of 100 successfully perturbed
# apgd-ce - 4/92 - 63 out of 100 successfully perturbed
# apgd-ce - 5/92 - 62 out of 100 successfully perturbed
# apgd-ce - 6/92 - 67 out of 100 successfully perturbed
# apgd-ce - 7/92 - 67 out of 100 successfully perturbed
# apgd-ce - 8/92 - 68 out of 100 successfully perturbed
# apgd-ce - 9/92 - 58 out of 100 successfully perturbed
# apgd-ce - 10/92 - 63 out of 100 successfully perturbed
# apgd-ce - 11/92 - 60 out of 100 successfully perturbed
# apgd-ce - 12/92 - 65 out of 100 successfully perturbed
# apgd-ce - 13/92 - 64 out of 100 successfully perturbed
# apgd-ce - 14/92 - 62 out of 100 successfully perturbed
# apgd-ce - 15/92 - 67 out of 100 successfully perturbed
# apgd-ce - 16/92 - 58 out of 100 successfully perturbed
# apgd-ce - 17/92 - 68 out of 100 successfully perturbed
# apgd-ce - 18/92 - 67 out of 100 successfully perturbed
# apgd-ce - 19/92 - 61 out of 100 successfully perturbed
# apgd-ce - 20/92 - 66 out of 100 successfully perturbed
# apgd-ce - 21/92 - 62 out of 100 successfully perturbed
# apgd-ce - 22/92 - 69 out of 100 successfully perturbed
# apgd-ce - 23/92 - 74 out of 100 successfully perturbed
# apgd-ce - 24/92 - 66 out of 100 successfully perturbed
# apgd-ce - 25/92 - 69 out of 100 successfully perturbed
# apgd-ce - 26/92 - 61 out of 100 successfully perturbed
# apgd-ce - 27/92 - 60 out of 100 successfully perturbed
# apgd-ce - 28/92 - 65 out of 100 successfully perturbed
# apgd-ce - 29/92 - 55 out of 100 successfully perturbed
# apgd-ce - 30/92 - 67 out of 100 successfully perturbed
# apgd-ce - 31/92 - 62 out of 100 successfully perturbed
# apgd-ce - 32/92 - 65 out of 100 successfully perturbed
# apgd-ce - 33/92 - 61 out of 100 successfully perturbed
# apgd-ce - 34/92 - 56 out of 100 successfully perturbed
# apgd-ce - 35/92 - 60 out of 100 successfully perturbed
# apgd-ce - 36/92 - 64 out of 100 successfully perturbed
# apgd-ce - 37/92 - 69 out of 100 successfully perturbed
# apgd-ce - 38/92 - 59 out of 100 successfully perturbed
# apgd-ce - 39/92 - 54 out of 100 successfully perturbed
# apgd-ce - 40/92 - 57 out of 100 successfully perturbed
# apgd-ce - 41/92 - 60 out of 100 successfully perturbed
# apgd-ce - 42/92 - 64 out of 100 successfully perturbed
# apgd-ce - 43/92 - 66 out of 100 successfully perturbed
# apgd-ce - 44/92 - 52 out of 100 successfully perturbed
# apgd-ce - 45/92 - 59 out of 100 successfully perturbed
# apgd-ce - 46/92 - 68 out of 100 successfully perturbed
# apgd-ce - 47/92 - 68 out of 100 successfully perturbed
# apgd-ce - 48/92 - 64 out of 100 successfully perturbed
# apgd-ce - 49/92 - 65 out of 100 successfully perturbed
# apgd-ce - 50/92 - 59 out of 100 successfully perturbed
# apgd-ce - 51/92 - 68 out of 100 successfully perturbed
# apgd-ce - 52/92 - 68 out of 100 successfully perturbed
# apgd-ce - 53/92 - 66 out of 100 successfully perturbed
# apgd-ce - 54/92 - 65 out of 100 successfully perturbed
# apgd-ce - 55/92 - 65 out of 100 successfully perturbed
# apgd-ce - 56/92 - 69 out of 100 successfully perturbed
# apgd-ce - 57/92 - 55 out of 100 successfully perturbed
# apgd-ce - 58/92 - 68 out of 100 successfully perturbed
# apgd-ce - 59/92 - 68 out of 100 successfully perturbed
# apgd-ce - 60/92 - 74 out of 100 successfully perturbed
# apgd-ce - 61/92 - 62 out of 100 successfully perturbed
# apgd-ce - 62/92 - 64 out of 100 successfully perturbed
# apgd-ce - 63/92 - 65 out of 100 successfully perturbed
# apgd-ce - 64/92 - 70 out of 100 successfully perturbed
# apgd-ce - 65/92 - 53 out of 100 successfully perturbed
# apgd-ce - 66/92 - 59 out of 100 successfully perturbed
# apgd-ce - 67/92 - 63 out of 100 successfully perturbed
# apgd-ce - 68/92 - 76 out of 100 successfully perturbed
# apgd-ce - 69/92 - 64 out of 100 successfully perturbed
# apgd-ce - 70/92 - 56 out of 100 successfully perturbed
# apgd-ce - 71/92 - 67 out of 100 successfully perturbed
# apgd-ce - 72/92 - 61 out of 100 successfully perturbed
# apgd-ce - 73/92 - 54 out of 100 successfully perturbed
# apgd-ce - 74/92 - 66 out of 100 successfully perturbed
# apgd-ce - 75/92 - 66 out of 100 successfully perturbed
# apgd-ce - 76/92 - 63 out of 100 successfully perturbed
# apgd-ce - 77/92 - 68 out of 100 successfully perturbed
# apgd-ce - 78/92 - 67 out of 100 successfully perturbed
# apgd-ce - 79/92 - 58 out of 100 successfully perturbed
# apgd-ce - 80/92 - 72 out of 100 successfully perturbed
# apgd-ce - 81/92 - 55 out of 100 successfully perturbed
# apgd-ce - 82/92 - 68 out of 100 successfully perturbed
# apgd-ce - 83/92 - 63 out of 100 successfully perturbed
# apgd-ce - 84/92 - 66 out of 100 successfully perturbed
# apgd-ce - 85/92 - 52 out of 100 successfully perturbed
# apgd-ce - 86/92 - 63 out of 100 successfully perturbed
# apgd-ce - 87/92 - 68 out of 100 successfully perturbed
# apgd-ce - 88/92 - 63 out of 100 successfully perturbed
# apgd-ce - 89/92 - 58 out of 100 successfully perturbed
# apgd-ce - 90/92 - 66 out of 100 successfully perturbed
# apgd-ce - 91/92 - 69 out of 100 successfully perturbed
# apgd-ce - 92/92 - 35 out of 59 successfully perturbed
# robust accuracy after APGD-CE: 33.21% (total time 276.2 s)
# apgd-t - 1/34 - 11 out of 100 successfully perturbed
# apgd-t - 2/34 - 16 out of 100 successfully perturbed
# apgd-t - 3/34 - 22 out of 100 successfully perturbed
# apgd-t - 4/34 - 21 out of 100 successfully perturbed
# apgd-t - 5/34 - 11 out of 100 successfully perturbed
# apgd-t - 6/34 - 26 out of 100 successfully perturbed
# apgd-t - 7/34 - 16 out of 100 successfully perturbed
# apgd-t - 8/34 - 13 out of 100 successfully perturbed
# apgd-t - 9/34 - 28 out of 100 successfully perturbed
# apgd-t - 10/34 - 18 out of 100 successfully perturbed
# apgd-t - 11/34 - 19 out of 100 successfully perturbed
# apgd-t - 12/34 - 18 out of 100 successfully perturbed
# apgd-t - 13/34 - 26 out of 100 successfully perturbed
# apgd-t - 14/34 - 20 out of 100 successfully perturbed
# apgd-t - 15/34 - 19 out of 100 successfully perturbed
# apgd-t - 16/34 - 26 out of 100 successfully perturbed
# apgd-t - 17/34 - 21 out of 100 successfully perturbed
# apgd-t - 18/34 - 27 out of 100 successfully perturbed
# apgd-t - 19/34 - 23 out of 100 successfully perturbed
# apgd-t - 20/34 - 15 out of 100 successfully perturbed
# apgd-t - 21/34 - 18 out of 100 successfully perturbed
# apgd-t - 22/34 - 25 out of 100 successfully perturbed
# apgd-t - 23/34 - 19 out of 100 successfully perturbed
# apgd-t - 24/34 - 22 out of 100 successfully perturbed
# apgd-t - 25/34 - 20 out of 100 successfully perturbed
# apgd-t - 26/34 - 22 out of 100 successfully perturbed
# apgd-t - 27/34 - 17 out of 100 successfully perturbed
# apgd-t - 28/34 - 26 out of 100 successfully perturbed
# apgd-t - 29/34 - 13 out of 100 successfully perturbed
# apgd-t - 30/34 - 16 out of 100 successfully perturbed
# apgd-t - 31/34 - 20 out of 100 successfully perturbed
# apgd-t - 32/34 - 18 out of 100 successfully perturbed
# apgd-t - 33/34 - 18 out of 100 successfully perturbed
# apgd-t - 34/34 - 5 out of 21 successfully perturbed
# robust accuracy after APGD-T: 26.66% (total time 806.0 s)
# fab-t - 1/27 - 4 out of 100 successfully perturbed
# fab-t - 2/27 - 3 out of 100 successfully perturbed
# fab-t - 3/27 - 2 out of 100 successfully perturbed
# fab-t - 4/27 - 5 out of 100 successfully perturbed
# fab-t - 5/27 - 5 out of 100 successfully perturbed
# fab-t - 6/27 - 2 out of 100 successfully perturbed
# fab-t - 7/27 - 3 out of 100 successfully perturbed
# fab-t - 8/27 - 3 out of 100 successfully perturbed
# fab-t - 9/27 - 2 out of 100 successfully perturbed
# fab-t - 10/27 - 1 out of 100 successfully perturbed
# fab-t - 11/27 - 0 out of 100 successfully perturbed
# fab-t - 12/27 - 3 out of 100 successfully perturbed
# fab-t - 13/27 - 1 out of 100 successfully perturbed
# fab-t - 14/27 - 6 out of 100 successfully perturbed
# fab-t - 15/27 - 4 out of 100 successfully perturbed
# fab-t - 16/27 - 5 out of 100 successfully perturbed
# fab-t - 17/27 - 3 out of 100 successfully perturbed
# fab-t - 18/27 - 2 out of 100 successfully perturbed
# fab-t - 19/27 - 3 out of 100 successfully perturbed
# fab-t - 20/27 - 3 out of 100 successfully perturbed
# fab-t - 21/27 - 3 out of 100 successfully perturbed
# fab-t - 22/27 - 2 out of 100 successfully perturbed
# fab-t - 23/27 - 2 out of 100 successfully perturbed
# fab-t - 24/27 - 5 out of 100 successfully perturbed
# fab-t - 25/27 - 2 out of 100 successfully perturbed
# fab-t - 26/27 - 2 out of 100 successfully perturbed
# fab-t - 27/27 - 3 out of 66 successfully perturbed
# robust accuracy after FAB-T: 25.87% (total time 2141.3 s)
# square - 1/26 - 1 out of 100 successfully perturbed
# square - 2/26 - 0 out of 100 successfully perturbed
# square - 3/26 - 0 out of 100 successfully perturbed
# square - 4/26 - 0 out of 100 successfully perturbed
# square - 5/26 - 0 out of 100 successfully perturbed
# square - 6/26 - 0 out of 100 successfully perturbed
# square - 7/26 - 0 out of 100 successfully perturbed
# square - 8/26 - 0 out of 100 successfully perturbed
# square - 9/26 - 0 out of 100 successfully perturbed
# square - 10/26 - 0 out of 100 successfully perturbed
# square - 11/26 - 0 out of 100 successfully perturbed
# square - 12/26 - 0 out of 100 successfully perturbed
# square - 13/26 - 0 out of 100 successfully perturbed
# square - 14/26 - 0 out of 100 successfully perturbed
# square - 15/26 - 0 out of 100 successfully perturbed
# square - 16/26 - 0 out of 100 successfully perturbed
# square - 17/26 - 0 out of 100 successfully perturbed
# square - 18/26 - 1 out of 100 successfully perturbed
# square - 19/26 - 0 out of 100 successfully perturbed
# square - 20/26 - 0 out of 100 successfully perturbed
# square - 21/26 - 0 out of 100 successfully perturbed
# square - 22/26 - 0 out of 100 successfully perturbed
# square - 23/26 - 0 out of 100 successfully perturbed
# square - 24/26 - 0 out of 100 successfully perturbed
# square - 25/26 - 0 out of 100 successfully perturbed
# square - 26/26 - 0 out of 87 successfully perturbed
# robust accuracy after SQUARE: 25.85% (total time 3869.6 s)
# max Linf perturbation: 0.03100, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 25.85%

# %%
adv_loader_Linf = torch.utils.data.DataLoader(adv_complete, batch_size=100, shuffle=False, num_workers=2)
num_total_images = 0
num_successful_attacks = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
    for adv_images in adv_loader_Linf:
        adv_images = adv_images.to(device)
        outputs_adv = net(adv_images)
        _, predicted_adv = torch.max(outputs_adv.data, 1)

        # Count the number of adversarial examples that were successfully attacked
        for i in range(len(images)):
            if predicted[i] != predicted_adv[i]:
                num_successful_attacks += 1
        
        # Increment the total number of images
        num_total_images += len(images)

# Calculate the adversarial attack rate
attack_rate = (num_successful_attacks / num_total_images) * 100
print(f"Adversarial attack rate: {attack_rate:.2f}%")
# Out:
# Adversarial attack rate: 89.60%

# %%
from autoattack import AutoAttack
adversary_L2 = AutoAttack(net, norm='L2', eps=0.031, version='standard')
adv_complete_L2 = adversary_L2.run_standard_evaluation(x_test, y_test,bs=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from autoattack import AutoAttack
# ----> 2 adversary_L2 = AutoAttack(net, norm='L2', eps=0.031, version='standard')
#       3 adv_complete_L2 = adversary_L2.run_standard_evaluation(x_test, y_test,bs=100)
#
# NameError: name 'net' is not defined

# %%
adv_loader_L2 = torch.utils.data.DataLoader(adv_complete_L2, batch_size=100, shuffle=False, num_workers=2)
num_total_images = 0
num_successful_attacks = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
    for adv_images in adv_loader_L2:
        adv_images = adv_images.to(device)
        outputs_adv = net(adv_images)
        _, predicted_adv = torch.max(outputs_adv.data, 1)

        # Count the number of adversarial examples that were successfully attacked
        for i in range(len(images)):
            if predicted[i] != predicted_adv[i]:
                num_successful_attacks += 1
        
        # Increment the total number of images
        num_total_images += len(images)

# Calculate the adversarial attack rate
attack_rate = (num_successful_attacks / num_total_images) * 100
print(f"Adversarial attack rate: {attack_rate:.2f}%")
